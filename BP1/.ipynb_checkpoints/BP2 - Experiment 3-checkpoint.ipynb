# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %%
from sklearn.exceptions import UndefinedMetricWarning
import warnings

warnings.filterwarnings(action='ignore', category=UndefinedMetricWarning)

# %%
data_ = pd.read_csv('datasets/diamonds.csv')
data_.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
data = data_.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
# Unnamed: 0    53940 non-null int64
# carat         53940 non-null float64
# cut           53940 non-null object
# color         53940 non-null object
# clarity       53940 non-null object
# depth         53940 non-null float64
# table         53940 non-null float64
# price         53940 non-null int64
# x             53940 non-null float64
# y             53940 non-null float64
# z             53940 non-null float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
data_ = data_.drop(['Unnamed: 0', 'clarity', 'color'], axis=1)

# %%
from sklearn import model_selection

array = data.values
Y = data_.pop('cut').values
X = data_.values
validation_size = 0.20
seed = 7
X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(X, Y, test_size=validation_size, random_state=seed)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y_train = le.fit_transform(Y_train)
Y_validation = le.fit_transform(Y_validation)

# %%
from sympy.logic import simplify_logic
from sympy.abc import x, y, z
from sympy import *
from sympy.logic.boolalg import *
from sympy.logic.inference import satisfiable

from pyeda.inter import *
from itertools import product
from pypred import OptimizedPredicateSet, PredicateSet, Predicate
from collections import OrderedDict

import uuid
import operator

import graphviz
from sklearn import tree


from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score


def viz_tree(clf, class_names, feature_names):
    tree_ = tree.export_graphviz(clf, out_file = None, filled=True, rounded=True, class_names=class_names, feature_names=feature_names)
    graph = graphviz.Source(tree_)
    return graph


def get_truth(inp, relate, cut):
    ops = {'>': operator.gt,
           '<': operator.lt,
           '>=': operator.ge,
           '<=': operator.le,
           '=': operator.eq}
    return ops[relate](inp, cut)


def get_leaf_class_name(class_names, node_values):
    max_value_index = 0
    max_value = 0
    for c, value in enumerate(node_values[0]):
        if value != 0 and value > max_value:
            max_value_index = c
            max_value = value
    
    return class_names[max_value_index]

        
def get_node_value(node_values):
    max_ = 0
    for c, value in enumerate(node_values[0]):
        if value > max_:
            max_ = value
            
    return max_
        
        
def get_paths_for(class_name, tree, cur_index, lst, paths, sign):
    if cur_index >= len(tree.children_left):
        return
    
    if len(lst) > 0 and cur_index != -1:
        lst[len(lst) - 1] = (lst[len(lst) - 1][0], lst[len(lst) - 1][1], sign, lst[len(lst) - 1][3])
        
    lst.append((cur_index, tree.feature[cur_index], sign, round(tree.threshold[cur_index], 2)))
    if cur_index != -1:
        get_paths_for(class_name, tree, tree.children_left[cur_index], lst, paths, '<=')
        get_paths_for(class_name, tree, tree.children_right[cur_index], lst, paths, '>')
    else:
        if get_leaf_class_name(data['cut'].unique(), tree.value[list(lst[-2])[0]]) == class_name:
            paths.add(tuple(lst[:-1]))
        
    lst.pop()
    
    
def get_feature_value_pairs(tree, paths):
    
    pairs = []
    for path in paths:
        d = []
        features = tree.feature
        thresholds = tree.threshold

        for i, p in enumerate(list(path[:-1])):
            d.append((i, features[i], thresholds[i]))

        pairs.append(d)
        
    return pairs


def rule_predict(class_name, rule):
    pred = []
    
    for row in X_validation:
        
        valid = True
        for condition in rule[:-1]:
            condition = list(condition)
            
            if not get_truth(row[condition[1]], condition[2], condition[3]):
                valid = False
            
        if valid:
            pred.append(class_name)
        else:
            pred.append(-1)
            
    return pred


# Function which computes rule accuracy based. It makes a classification report and takes
# the precision value and returns it
def compute_rule_accuracy(class_name, rule):
    pred = rule_predict(class_name, rule)
    report = classification_report(pred, Y_validation, output_dict = True)
    
    return round(report[str(class_name)]['precision'], 2)


def prune_rule(class_name, rule):
    max_accuracy = 0
    final_rule = rule
    
    for i in range(len(rule[:-1])):
        accuracy = compute_rule_accuracy(class_name, rule[i:])
        
        if accuracy > max_accuracy:
            final_rule = rule[i:]
            max_accuracy = accuracy
           
    return (max_accuracy, tuple(final_rule))


def combine_rules(class_name, rf_model):
    rules = set()
    
    for estimator in rf_model.estimators_:
        get_paths_for(class_name, estimator.tree_, 0, [], rules, '<=')
        
    return rules


def get_class_index(class_name):
    for c, cls in enumerate(data['cut'].unique()):
        if cls == class_name:
            return c
        
        
def get_rules_accuracy(class_name, rf_model, removeRedundancy = False):
    rules = combine_rules(class_name, rf_model)
    
    if removeRedundancy:
        rules = redundancy_condition_removal(rules)
    
    rules = list(rules)
    
    final_rules = set()
    for rule in rules:
        rule_ = [compute_rule_accuracy(get_class_index(class_name), rule), rule]
        final_rules.add(tuple(rule_))
        
    return sorted(list(final_rules), reverse=True, key=lambda x: list(x)[0])
    
        
def get_pruned_rules_accuracy(class_name, rf_model):
    rules = list(combine_rules(class_name, rf_model))
    
    final_rules = set()
    for rule in rules:
        pruned = prune_rule(get_class_index(class_name), list(rule))
        final_rules.add(tuple(pruned))
    
    return sorted(list(final_rules), reverse=True, key=lambda x: list(x)[0])


def redundancy_condition_removal(rule_set):
    output = set()
    
    for rule in list(rule_set):
        
        rule = list(rule)
        for i, cond in enumerate(rule[:-1]):
            cond = list(cond)
            
            for cond2 in rule[i + 1:-1]:
                cond2 = list(cond2)
                    
                if cond[1] == cond2[1] and cond[2] == cond2[2]:
                    if cond[2] == '>':
                        cond[3] = (cond[3] if cond[3] > cond2[3] else cond2[3])
                    else:
                        cond[3] = (cond[3] if cond[3] < cond2[3] else cond2[3])
                        
                    # Assign changed rule to condition
                    rule[i] = tuple(cond)
                    
                    # Remove redundant rule from list
                    rule.remove(tuple(cond2))
                
        output.add(tuple(rule))
        
    return output


def create_big_or_rule(rule_set):
    output = ""
    for i, rule in enumerate(list(rule_set)):
        output += create_and_expression(rule)
        
        if len(rule_set) - 1 != i:
            output += " | "
            
    return output


def create_big_and_rule(rule_set):
    output = ""
    for i, rule in enumerate(list(rule_set)):
        output += create_and_expression(rule)
        
        if len(rule_set) - 1 != i:
            output += " & "
            
    return output


def combine_rule_using_and(rule_set, sign):
    output = ""
    for i, rule in enumerate(list(rule_set)):
        output += "(" + rule + ")"
            
        if len(rule_set) - 1 != i:
            output += " " + sign + " "
            
    return output


def create_and_expression(rule):
    output = ""
    
    for i, condition in enumerate(list(rule)[:-1]):
        condition = list(condition)
        key = str(condition[1]) + str(condition[3])
        
        var = "A" + uuid.uuid4().hex[:6].upper()
        
        if key in rule_dict:
            if condition[2] != rule_dict[key][0]:
                output += "Not(" + rule_dict[key][1] + ")"
            else:
                output += rule_dict[key][1]
        else:
            expr = var + ' = ' + 'symbols(\'' + (str(condition[1]) + condition[2] + str(condition[3])) + '\')'
            exec(expr)
            
            rule_dict[key] = [condition[2], var]
            output += var
        
            # Also push to rule_dict where key is the variable name and value is the rule
            var_dict[var] = condition
        
        if len(list(rule)[:-1]) - 1 != i:
            output += " & "
        
    return "(" + output + ")"


def print_final_rule(simplified_rule):
    simplified_rule = str(simplified_rule).split()
    
    final_rule = ""
    for el in simplified_rule:
        if el in ('&', '|'):
            final_rule += " " + el + " "
        else:
            if "~" in el:
                el = el.replace("~", "")
                el_ = el
                
                lb_count = el_.count('(')
                if "(" in el_:
                    el_ = el_.replace("(", "")
                
                rb_count = el_.count(')')
                if ")" in el_:
                    el_ = el_.replace(")", "")
                
                var = var_dict[str(el_)].copy()[1:]
                if var[1] == '>':
                    var[1] = '<='
                else:
                    var[1] = '>'
                  
                if lb_count == 0 and rb_count == 0:
                    final_rule += str(tuple(var))
                elif lb_count != 0 and rb_count == 0:
                    final_rule += ("(" * lb_count) + str(tuple(var))
                elif lb_count == 0 and rb_count != 0:
                    final_rule += str(tuple(var)) + (")" * rb_count)
            
            elif "(" in el:
                b_count = el.count('(')
                
                el = el.replace("(", "")
                final_rule += ("(" * b_count) + str(tuple(var_dict[str(el)][1:]))
                
            elif ")" in el:
                b_count = el.count(')')
                
                el = el.replace(")", "")
                final_rule += str(tuple(var_dict[str(el)][1:])) + (")" * b_count)
            
            else:
                final_rule += str(tuple(var_dict[str(el)][1:]))
            
    return final_rule


def convert_to_function(sign, expr_):
    rule = ""
    for i, el in enumerate(expr_.xs):
        if "And" in str(el):
            rule += "(" + convert_to_function("&", el) + ")"
        elif "Or" in str(el):
            rule += "(" + convert_to_function("|", el) + ")"
        else:
            rule += str(el)
            
        if i != len(expr_.xs) - 1:
            rule += " " + sign + " "
            
    return rule
    
    
def predict_rule_class(rule_set):
    X = X_train
    Y = Y_train
    
    Z = predicate_rules_set_predict(rules_set, X_validation)
    
    print(accuracy_score(Y_validation, Z))
    print(classification_report(Z, Y_validation))


def visualize_decision_boundaries(rule, attr1, attr2):
    """
    This function is used to draw decision boundaries for 2 attributes which will be used to predict the output
    """
    
    # Create a dataset from validation data having only columns specified by paramters
    X = X_validation[:, [attr1, attr2]]
    Y = Y_validation

    # Plotting decision regions
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))

    f, axarr = plt.subplots(figsize=(10, 8))

    # Create prediction
    ravel_ = np.c_[xx.ravel(), yy.ravel()]
    Z = np.array(attribute_rule_predict(1, rule, attr1, attr2, ravel_))
    Z = Z.reshape(xx.shape)
    
    # Plot predicted dots
    axarr.contourf(xx, yy, Z, alpha=0.5)
    axarr.scatter(X[:, 0], X[:, 1], c=Y, s=50, edgecolor='k')
    axarr.set_title("When random forest is very sure")

    plt.show()
    
    
def predicate_rules_set_predict(rules_set, dataset):
    
    pred = []
    
    df_columns = list(data.columns.values[:-1])
    d_ = OrderedDict()
    
    w_set = set()
    for r in rules_set:
        r = (r[0], OptimizedPredicateSet([Predicate(r[1])]))
        w_set.add(r)
        
    for i, row in enumerate(dataset):
        
        
        for l, at in enumerate(df_columns):
            d_[at] = row[l]
            
        
        j = 0
        for r in w_set:
            class_i = r[0]
            rule_p = r[1]

            match = rule_p.evaluate(dict(d_))

            if len(match):
                pred.append(class_i)
                break
        
            j += 1
            
        if j == len(w_set):
            pred.append(-1)
        
    return pred


def redundancy_condition_removal_(rule_set):
    output = set()
    
    for rule in list(rule_set):
        
        rule = list(rule)
        for i, cond in enumerate(rule):
            cond = list(cond)
            
            for cond2 in rule[i + 1:]:
                cond2 = list(cond2)
                    
                if cond[0] == cond2[0] and cond[1] == cond2[1]:
                    if cond[1] == '>':
                        cond[2] = (cond[2] if cond[2] > cond2[2] else cond2[2])
                    else:
                        cond[2] = (cond[2] if cond[2] < cond2[2] else cond2[2])
                        
                    # Assign changed rule to condition
                    rule[i] = tuple(cond)
                    
                    # Remove redundant rule from list
                    rule.remove(tuple(cond2))
                
        output.add(tuple(rule))
        
    return output


def split_rules(rule_str):
    redundant_rules_set = set()
    composed_rules_set = set()
    
    rule = ""
    stack = []
    
    for c in rule_str:
        
        if c in (' ', '&', '|') and len(stack) == 0:
            continue
            
        rule += c
        
        if c == "(":
            stack.append(c)
        
        if c == ")" and len(stack) == 1:
            stack.pop()
            
            if len(stack) == 0:
                try:
                    redundant_rules_set.add(eval(rule))
                except:
                    composed_rules_set.add(rule)
            
            rule = ""
            
        elif c == ')':
            stack.pop()
            
    return redundant_rules_set, composed_rules_set


def compose_final_rule(no_redundant_rules, composed_rules_set):
    final_rule = ""
    
    for i, rule in enumerate(no_redundant_rules):
        final_rule += str(rule) + " & "
            
    for i, rule in enumerate(composed_rules_set):
        final_rule += rule
        
        if len(composed_rules_set) - 1 != i:
            final_rule += " & "
        
    return final_rule

# %%
def attribute_rule_predict(class_name, rule, attr1, attr2, dataset):
    """Method used to get prediction only for two attributes given by 'attr1' and 'attr2' parameters
    This method is mainly used mainly for plotting purposes
    """ 
    
    # Create an empty predictions array
    pred = []
    
    # Create and optimize predicate given by the parameter
    test = Predicate(rule)
    s = OptimizedPredicateSet([test])
    
    # Store dataframe attribute names
    df_columns = list(data_.columns.values)
    
    # Create dictionary in which we will create the predicate
    d_ = dict()
    
    for row in dataset:
        
        # Get the attribute names by indexes from df_columns.
        d_[df_columns[attr1]] = row[0]
        d_[df_columns[attr2]] = row[1]
    
        # Evaluate rule with created dictionary
        match = s.evaluate(d_)
            
        # If the conditions from rule were met, append the class to final predictions array
        if len(match):
            pred.append(class_name)
        else:
            pred.append(-1)
            
    return pred

# %%
def get_valid_predicate(rule):
    rule = rule.replace("&", "and").replace("|", "or").replace("0, '", 'carat ').replace("1, '", 'depth ')
    rule = rule.replace("2, '", 'table ').replace("3, '", 'price ')
    rule = rule.replace("4, '", 'x ').replace("5, '", 'y ').replace("6, '", 'z ')
    rule = rule.replace("',", "")
    
    return rule

# %%
def combine_forest_rules(rf_model, class_name, r_dict, v_dict):
    final_rule = set()
    simplified_final_rule = set()
    for estimator in rf_model.estimators_:
    
        rules = set()
        get_paths_for(class_name, estimator.tree_, 0, [], rules, '<=')
        
        if len(rules):
            rules = redundancy_condition_removal(rules)
            tree_rule = sympify(create_big_or_rule(rules), evaluate=False)

            final_rule.add(str(tree_rule))

            expr_ = expr(str(tree_rule))
            o1, expr_ = espresso_exprs(expr_, expr_)

            expr_ = convert_to_function(('|' if str(expr_).split('(', 1)[0] == "Or" else '&'), expr_)
            simplified_final_rule.add(expr_)
        
        
    return final_rule, simplified_final_rule

# %%
from sklearn.ensemble import RandomForestClassifier

rfclf = RandomForestClassifier(n_estimators=5, max_depth=4)
rfclf.fit(X_train, Y_train)

pred = rfclf.predict(X_validation)

# %%
rule_dict = {}
var_dict = {}

rules, s_rules = combine_forest_rules(rfclf, "Fair", rule_dict, var_dict)
rules
# Out:
# {'(A209C5D & A442A9D & A56CC3A) | (A56CC3A & A702D62 & ADE1B6D & ~A442A9D) | (A2EFA61 & AF809FD & ~A56CC3A & ~AD193B3) | (AD193B3 & AF809FD & ~A56CC3A & ~A702D62)',
#  '(A3F121C & AA56AD6 & ABFD1D7) | (A114C73 & A59C64A & AB7327B & AED6EAF) | (A59C64A & A702D62 & AEFB0C2 & ~AB7327B) | (A4313A3 & A88D8B2 & ~A3F121C & ~A59C64A)',
#  '(A442A9D & AF809FD & ~A702D62) | (A702D62 & A7F3AA6 & A89E0F0 & AD208C3) | (A6272F9 & A666E56 & ABD5E13 & ~A702D62) | (A702D62 & A7F3AA6 & A939100 & ~AD208C3)',
#  '(A981F64 & AAA693A & AB7327B) | (A8546C2 & A8A5510 & ~AB7327B) | (A0B6CB5 & AA613B4 & AB7327B & AED6EAF) | (A0AE812 & A88D8B2 & A8A246F & ~AB7327B) | (A88D8B2 & AE346F8 & ~A8A246F & ~AB7327B)',
#  '(AAA693A & AB7327B & ADE8EF8) | (A702D62 & A7F3AA6 & A8A246F & ~AB7327B) | (A3F121C & A88D8B2 & ~A702D62 & ~AB7327B)'}

# %%
s_rules
# Out:
# {'(A209C5D & A442A9D & A56CC3A) | (A702D62 & ~A442A9D & A56CC3A & ADE1B6D) | (~A702D62 & ~A56CC3A & AF809FD & AD193B3) | (~A56CC3A & A2EFA61 & AF809FD & ~AD193B3)',
#  '(A59C64A & ~AB7327B & A702D62 & AEFB0C2) | (A114C73 & A59C64A & AB7327B & AED6EAF) | (A3F121C & AA56AD6 & ABFD1D7) | (~A3F121C & ~A59C64A & A4313A3 & A88D8B2)',
#  '(~A702D62 & A6272F9 & A666E56 & ABD5E13) | (A702D62 & A7F3AA6 & A89E0F0 & AD208C3) | (~A702D62 & A442A9D & AF809FD) | (A702D62 & A7F3AA6 & ~AD208C3 & A939100)',
#  '(~AB7327B & A702D62 & A8A246F & A7F3AA6) | (A3F121C & ~AB7327B & ~A702D62 & A88D8B2) | (AB7327B & AAA693A & ADE8EF8)',
#  '(~AB7327B & A88D8B2 & ~A8A246F & AE346F8) | (~AB7327B & A8546C2 & A8A5510) | (~AB7327B & A88D8B2 & A0AE812 & A8A246F) | (AB7327B & AED6EAF & A0B6CB5 & AA613B4) | (AB7327B & A981F64 & AAA693A)'}

# %%
simplified_func = convert_to_function('&', s)
simplified_func
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-6fa1e85dc53e> in <module>
# ----> 1 simplified_func = convert_to_function('&', s)
#       2 simplified_func
#
# <ipython-input-8-b3cb3d12c972> in convert_to_function(sign, expr_)
#     321 def convert_to_function(sign, expr_):
#     322     rule = ""
# --> 323     for i, el in enumerate(expr_.xs):
#     324         if "And" in str(el):
#     325             rule += "(" + convert_to_function("&", el) + ")"
#
# AttributeError: 'str' object has no attribute 'xs'

# %%
sys_readable_rule = print_final_rule(s)
sys_readable_rule
# Out:
# "(((4, '>', 4.23) & (5, '<=', 4.28) & (2, '<=', 57.05)) | ((1, '>', 63.05) & (5, '>', 4.28) & (2, '<=', 57.05) & (0, '>', 0.67)) | ((1, '<=', 63.05) & (2, '>', 57.05) & (4, '<=', 4.26) & (3, '<=', 644.0)) | ((2, '>', 57.05) & (5, '>', 4.17) & (4, '<=', 4.26) & (3, '>', 644.0))) & (((2, '<=', 57.15) & (1, '>', 63.05) & (4, '>', 5.17) & (1, '<=', 64.35)) | ((4, '<=', 4.28) & (2, '<=', 57.15) & (1, '<=', 63.05) & (1, '>', 62.85)) | ((2, '>', 57.15) & (0, '<=', 0.3) & (6, '<=', 2.6))) & (((1, '<=', 63.05) & (0, '<=', 1.01) & (4, '>', 6.08) & (5, '>', 6.56)) | ((1, '>', 63.05) & (1, '<=', 64.35) & (5, '<=', 4.24) & (0, '<=', 0.5)) | ((1, '<=', 63.05) & (5, '<=', 4.28) & (4, '<=', 4.26)) | ((1, '>', 63.05) & (1, '<=', 64.35) & (0, '>', 0.5) & (4, '>', 6.37))) & (((4, '>', 5.82) & (2, '<=', 57.15) & (1, '>', 63.05) & (5, '>', 6.32)) | ((0, '>', 0.83) & (4, '>', 5.82) & (2, '>', 57.15) & (4, '<=', 6.38)) | ((4, '<=', 4.28) & (2, '>', 57.5) & (3, '<=', 628.5)) | ((4, '>', 4.28) & (4, '<=', 5.82) & (0, '>', 0.63) & (1, '>', 62.85))) & (((2, '<=', 57.15) & (1, '>', 62.85) & (4, '<=', 5.17) & (3, '>', 827.5)) | ((2, '<=', 57.15) & (5, '<=', 4.37) & (1, '<=', 60.05)) | ((2, '<=', 57.15) & (1, '>', 62.85) & (0, '<=', 1.79) & (4, '>', 5.17)) | ((2, '>', 57.15) & (4, '<=', 6.38) & (0, '>', 0.44) & (5, '>', 6.34)) | ((2, '>', 57.15) & (3, '<=', 666.0) & (0, '<=', 0.3)))"

# %%
s = combine_rule_using_and(s_rules, '&')
s
# Out:
# '((A209C5D & A442A9D & A56CC3A) | (A702D62 & ~A442A9D & A56CC3A & ADE1B6D) | (~A702D62 & ~A56CC3A & AF809FD & AD193B3) | (~A56CC3A & A2EFA61 & AF809FD & ~AD193B3)) & ((~AB7327B & A702D62 & A8A246F & A7F3AA6) | (A3F121C & ~AB7327B & ~A702D62 & A88D8B2) | (AB7327B & AAA693A & ADE8EF8)) & ((~A702D62 & A6272F9 & A666E56 & ABD5E13) | (A702D62 & A7F3AA6 & A89E0F0 & AD208C3) | (~A702D62 & A442A9D & AF809FD) | (A702D62 & A7F3AA6 & ~AD208C3 & A939100)) & ((A59C64A & ~AB7327B & A702D62 & AEFB0C2) | (A114C73 & A59C64A & AB7327B & AED6EAF) | (A3F121C & AA56AD6 & ABFD1D7) | (~A3F121C & ~A59C64A & A4313A3 & A88D8B2)) & ((~AB7327B & A88D8B2 & ~A8A246F & AE346F8) | (~AB7327B & A8546C2 & A8A5510) | (~AB7327B & A88D8B2 & A0AE812 & A8A246F) | (AB7327B & AED6EAF & A0B6CB5 & AA613B4) | (AB7327B & A981F64 & AAA693A))'

# %%
hum_readable_rule = get_valid_predicate(sys_readable_rule)
hum_readable_rule
# Out:
# '(((x > 4.23) and (y <= 4.28) and (table <= 57.05)) or ((depth > 63.05) and (y > 4.28) and (table <= 57.05) and (carat > 0.67)) or ((depth <= 63.05) and (table > 57.05) and (x <= 4.26) and (price <= 644.0)) or ((table > 57.05) and (y > 4.17) and (x <= 4.26) and (price > 644.0))) and (((table <= 57.15) and (depth > 63.05) and (x > 5.17) and (depth <= 64.35)) or ((x <= 4.28) and (table <= 57.15) and (depth <= 63.05) and (depth > 62.85)) or ((table > 57.15) and (carat <= 0.3) and (z <= 2.6))) and (((depth <= 63.05) and (carat <= 1.01) and (x > 6.08) and (y > 6.56)) or ((depth > 63.05) and (depth <= 64.35) and (y <= 4.24) and (carat <= 0.5)) or ((depth <= 63.05) and (y <= 4.28) and (x <= 4.26)) or ((depth > 63.05) and (depth <= 64.35) and (carat > 0.5) and (x > 6.37))) and (((x > 5.82) and (table <= 57.15) and (depth > 63.05) and (y > 6.32)) or ((carat > 0.83) and (x > 5.82) and (table > 57.15) and (x <= 6.38)) or ((x <= 4.28) and (table > 57.5) and (price <= 628.5)) or ((x > 4.28) and (x <= 5.82) and (carat > 0.63) and (depth > 62.85))) and (((table <= 57.15) and (depth > 62.85) and (x <= 5.17) and (price > 827.5)) or ((table <= 57.15) and (y <= 4.37) and (depth <= 60.05)) or ((table <= 57.15) and (depth > 62.85) and (carat <= 1.79) and (x > 5.17)) or ((table > 57.15) and (x <= 6.38) and (carat > 0.44) and (y > 6.34)) or ((table > 57.15) and (price <= 666.0) and (carat <= 0.3)))'

# %%
def compute_rule_accuracy(class_name, rule, dataset):
    """This method allows you to evaluate the whole rule given by 'rule' parameter to 'class_name'
    Returns an array of evaluated rule
    """
    
    pred = []
    
    # Store dataframe attribute names
    df_columns = list(data_.columns.values)
    
    # Create an ordered dictionary in order to keep the order when we take values for given columns
    d_ = OrderedDict()
    
    # Create and optimize predicate given by the parameter
    test = Predicate(rule)
    s = OptimizedPredicateSet([test])
    
    for row in dataset:
        
        # Create dictionary consisting of attribute names and corresponding row values for them
        for l, at in enumerate(df_columns):
            d_[at] = row[l]
        
        # Evaluate rule with created dictionary
        match = s.evaluate(dict(d_))
            
        # If the conditions from rule were met, append the class to final predictions array
        if len(match):
            pred.append(class_name)
        else:
            pred.append(-1)
            
    return pred


def compute_final_rule_accuracy(class_index, rule):
    X = X_validation
    Y = Y_validation
    
    # Classification report
    Z = compute_rule_accuracy(class_index, rule, X)

    report = classification_report(Z, Y, output_dict = True)
    print(report[str(class_index)])

# %%
hum_readable_rule
# Out:
# '(((x > 4.23) and (y <= 4.28) and (table <= 57.05)) or ((depth > 63.05) and (y > 4.28) and (table <= 57.05) and (carat > 0.67)) or ((depth <= 63.05) and (table > 57.05) and (x <= 4.26) and (price <= 644.0)) or ((table > 57.05) and (y > 4.17) and (x <= 4.26) and (price > 644.0))) and (((table <= 57.15) and (depth > 63.05) and (x > 5.17) and (depth <= 64.35)) or ((x <= 4.28) and (table <= 57.15) and (depth <= 63.05) and (depth > 62.85)) or ((table > 57.15) and (carat <= 0.3) and (z <= 2.6))) and (((depth <= 63.05) and (carat <= 1.01) and (x > 6.08) and (y > 6.56)) or ((depth > 63.05) and (depth <= 64.35) and (y <= 4.24) and (carat <= 0.5)) or ((depth <= 63.05) and (y <= 4.28) and (x <= 4.26)) or ((depth > 63.05) and (depth <= 64.35) and (carat > 0.5) and (x > 6.37))) and (((x > 5.82) and (table <= 57.15) and (depth > 63.05) and (y > 6.32)) or ((carat > 0.83) and (x > 5.82) and (table > 57.15) and (x <= 6.38)) or ((x <= 4.28) and (table > 57.5) and (price <= 628.5)) or ((x > 4.28) and (x <= 5.82) and (carat > 0.63) and (depth > 62.85))) and (((table <= 57.15) and (depth > 62.85) and (x <= 5.17) and (price > 827.5)) or ((table <= 57.15) and (y <= 4.37) and (depth <= 60.05)) or ((table <= 57.15) and (depth > 62.85) and (carat <= 1.79) and (x > 5.17)) or ((table > 57.15) and (x <= 6.38) and (carat > 0.44) and (y > 6.34)) or ((table > 57.15) and (price <= 666.0) and (carat <= 0.3)))'

# %%
compute_final_rule_accuracy(4, hum_readable_rule)
# Out:
# {'precision': 0.06144329896907216, 'recall': 0.6056910569105691, 'f1-score': 0.11156870086110071, 'support': 246}

# %%
visualize_decision_boundaries(hum_readable_rule, 0, 1)

# %%
data['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
def compute_for_each_class(classes):

    for i, class_ in enumerate(classes):
        rule_dict = {}
        var_dict = {}

        rules, s_rules = combine_forest_rules(rfclf, class_, rule_dict, var_dict)
        print(" --------------------------------------- " + class_ + " --------------------------------------- ")
        print(" --------- Rules --------- ")
        print(rules)
        print(" --------- Simplified Rules --------- ")
        print(s_rules)
        
        print(" --------- Combine rules using & (AND) --------- ")
        r_and = combine_rule_using_and(s_rules, '&')
        print(r_and)
        
        print(" --------- Get System readable rule --------- ")
        and_sys_readable_rule = print_final_rule(r_and)
        print(and_sys_readable_rule)
        
        print(" --------- Get corresponding predicate --------- ")
        and_hum_readable_rule = get_valid_predicate(and_sys_readable_rule)
        print(and_hum_readable_rule)

        print(" --------- Calculate precision and recall --------- ")
        compute_final_rule_accuracy(i, and_hum_readable_rule)

        
        print(" ----------------------------------------- ")
        print(" ----------------------------------------- ")
        print(" --------- Combine rules using | (OR) --------- ")
        r_or = combine_rule_using_and(s_rules, '|')
        print(r_or)
        
        print(" --------- Get System readable rule --------- ")
        or_sys_readable_rule = print_final_rule(r_or)
        print(or_sys_readable_rule)
        
        print(" --------- Get corresponding predicate --------- ")
        or_hum_readable_rule = get_valid_predicate(or_sys_readable_rule)
        print(or_hum_readable_rule)

        print(" --------- Calculate precision and recall --------- ")
        compute_final_rule_accuracy(i, or_hum_readable_rule)
        
        print(" ----------------------------------------- ")
        print(" ----------------------------------------- ")
        print(" ")
        print(" ")
        print(" ")

# %%
compute_for_each_class(data['cut'].unique())
# Out:
#  --------------------------------------- Ideal ---------------------------------------
#  --------- Rules ---------
# {'A62EE0E & AAA91B0 & AB70C06 & ACFA3C3', 'A2E9856 & A7EB251 & A9E80D7', 'A2E9856 & A8D4C7B & AB70C06', 'A2DD9BF & A2E9856 & A8E7005'}
#  --------- Simplified Rules ---------
# {'A62EE0E & AAA91B0 & AB70C06 & ACFA3C3', 'A2E9856 & A7EB251 & A9E80D7', 'A2E9856 & A2DD9BF & A8E7005', 'A2E9856 & AB70C06 & A8D4C7B'}
#  --------- Combine rules using & (AND) ---------
# (A62EE0E & AAA91B0 & AB70C06 & ACFA3C3) & (A2E9856 & A7EB251 & A9E80D7) & (A2E9856 & A2DD9BF & A8E7005) & (A2E9856 & AB70C06 & A8D4C7B)
#  --------- Get System readable rule ---------
# ((0, '>', 1.79) & (4, '>', 5.17) & (2, '<=', 57.15) & (1, '>', 62.85)) & ((1, '>', 64.35) & (2, '>', 57.05) & (4, '>', 4.26)) & ((1, '>', 64.35) & (3, '>', 520.0) & (6, '>', 2.66)) & ((1, '>', 64.35) & (2, '<=', 57.15) & (4, '>', 4.25))
#  --------- Get corresponding predicate ---------
# ((carat > 1.79) and (x > 5.17) and (table <= 57.15) and (depth > 62.85)) and ((depth > 64.35) and (table > 57.05) and (x > 4.26)) and ((depth > 64.35) and (price > 520.0) and (z > 2.66)) and ((depth > 64.35) and (table <= 57.15) and (x > 4.25))
#  --------- Calculate precision and recall ---------
# {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}
#  -----------------------------------------
#  -----------------------------------------
#  --------- Combine rules using | (OR) ---------
# (A62EE0E & AAA91B0 & AB70C06 & ACFA3C3) | (A2E9856 & A7EB251 & A9E80D7) | (A2E9856 & A2DD9BF & A8E7005) | (A2E9856 & AB70C06 & A8D4C7B)
#  --------- Get System readable rule ---------
# ((0, '>', 1.79) & (4, '>', 5.17) & (2, '<=', 57.15) & (1, '>', 62.85)) | ((1, '>', 64.35) & (2, '>', 57.05) & (4, '>', 4.26)) | ((1, '>', 64.35) & (3, '>', 520.0) & (6, '>', 2.66)) | ((1, '>', 64.35) & (2, '<=', 57.15) & (4, '>', 4.25))
#  --------- Get corresponding predicate ---------
# ((carat > 1.79) and (x > 5.17) and (table <= 57.15) and (depth > 62.85)) or ((depth > 64.35) and (table > 57.05) and (x > 4.26)) or ((depth > 64.35) and (price > 520.0) and (z > 2.66)) or ((depth > 64.35) and (table <= 57.15) and (x > 4.25))
#  --------- Calculate precision and recall ---------
# {'precision': 0.7469135802469136, 'recall': 0.7831715210355987, 'f1-score': 0.764612954186414, 'support': 309}
#  -----------------------------------------
#  -----------------------------------------
#
#
#
#  --------------------------------------- Premium ---------------------------------------
#  --------- Rules ---------
# {'(A0D84A3 & A372806 & A805F86 & ~AB70C06) | (A1C8E29 & AB70C06 & ACFA3C3 & ~AAA91B0)', '(A2E9856 & AB70C06 & ~A8D4C7B) | (A282C08 & A372806 & A3C608D & ~AB70C06) | (A372806 & AB70C06 & ~A2E9856 & ~AAA91B0)', '(A2E9856 & ~A8E7005) | (A2E9856 & A8E7005 & ~A2DD9BF) | (A372806 & A58A172 & ABF7AC5 & ~A2E9856) | (A372806 & A63A9E5 & ~A2E9856 & ~A58A172)', '(A39B6EC & A68B8E0 & A72CB6F) | (A372806 & A3E6400 & ~AB70C06) | (A372806 & A9FCAAE & AB70C06 & AC21C76)', '(A7D7E75 & A7EB251 & A9E80D7) | (A080468 & A346AF2 & AECCA3D & ~A7EB251) | (A372806 & A7EB251 & A9E80D7 & ~A2E9856) | (A372806 & A7EB251 & AA34484 & ~A9E80D7) | (A346AF2 & AC6F94E & ~A080468 & ~A7EB251) | (AA1B333 & ACFA3C3 & ~A346AF2 & ~A7EB251)'}
#  --------- Simplified Rules ---------
# {'(~A7EB251 & ACFA3C3 & ~A346AF2 & AA1B333) | (~A7EB251 & ~A080468 & A346AF2 & AC6F94E) | (A7EB251 & A9E80D7 & A7D7E75) | (A7EB251 & ~A9E80D7 & A372806 & AA34484) | (~A7EB251 & A080468 & A346AF2 & AECCA3D) | (~A2E9856 & A7EB251 & A9E80D7 & A372806)', '(A2E9856 & AB70C06 & ~A8D4C7B) | (~A2E9856 & ~AAA91B0 & AB70C06 & A372806) | (~AB70C06 & A372806 & A282C08 & A3C608D)', '(A2E9856 & ~A2DD9BF) | (A2E9856 & ~A8E7005) | (~A2E9856 & A372806 & ~A58A172 & A63A9E5) | (~A2E9856 & A372806 & A58A172 & ABF7AC5)', '(A39B6EC & A68B8E0 & A72CB6F) | (AB70C06 & A372806 & A9FCAAE & AC21C76) | (~AB70C06 & A372806 & A3E6400)', '(~AB70C06 & A372806 & A0D84A3 & A805F86) | (~AAA91B0 & AB70C06 & ACFA3C3 & A1C8E29)'}
#  --------- Combine rules using & (AND) ---------
# ((~A7EB251 & ACFA3C3 & ~A346AF2 & AA1B333) | (~A7EB251 & ~A080468 & A346AF2 & AC6F94E) | (A7EB251 & A9E80D7 & A7D7E75) | (A7EB251 & ~A9E80D7 & A372806 & AA34484) | (~A7EB251 & A080468 & A346AF2 & AECCA3D) | (~A2E9856 & A7EB251 & A9E80D7 & A372806)) & ((A2E9856 & AB70C06 & ~A8D4C7B) | (~A2E9856 & ~AAA91B0 & AB70C06 & A372806) | (~AB70C06 & A372806 & A282C08 & A3C608D)) & ((A2E9856 & ~A2DD9BF) | (A2E9856 & ~A8E7005) | (~A2E9856 & A372806 & ~A58A172 & A63A9E5) | (~A2E9856 & A372806 & A58A172 & ABF7AC5)) & ((A39B6EC & A68B8E0 & A72CB6F) | (AB70C06 & A372806 & A9FCAAE & AC21C76) | (~AB70C06 & A372806 & A3E6400)) & ((~AB70C06 & A372806 & A0D84A3 & A805F86) | (~AAA91B0 & AB70C06 & ACFA3C3 & A1C8E29))
#  --------- Get System readable rule ---------
# (((2, '<=', 57.05) & (1, '>', 62.85) & (5, '>', 4.28) & (0, '<=', 0.67)) | ((2, '<=', 57.05) & (4, '<=', 4.22) & (5, '<=', 4.28) & (6, '>', 2.68)) | ((2, '>', 57.05) & (4, '>', 4.26) & (1, '<=', 58.15)) | ((2, '>', 57.05) & (4, '<=', 4.26) & (1, '>', 63.05) & (3, '<=', 644.0)) | ((2, '<=', 57.05) & (4, '>', 4.22) & (5, '<=', 4.28) & (4, '<=', 4.23)) | ((1, '<=', 64.35) & (2, '>', 57.05) & (4, '>', 4.26) & (1, '>', 63.05))) & (((1, '>', 64.35) & (2, '<=', 57.15) & (4, '<=', 4.25)) | ((1, '<=', 64.35) & (4, '<=', 5.17) & (2, '<=', 57.15) & (1, '>', 63.05)) | ((2, '>', 57.15) & (1, '>', 63.05) & (6, '>', 2.6) & (6, '<=', 2.98))) & (((1, '>', 64.35) & (3, '<=', 520.0)) | ((1, '>', 64.35) & (6, '<=', 2.66)) | ((1, '<=', 64.35) & (1, '>', 63.05) & (0, '>', 0.5) & (4, '<=', 6.37)) | ((1, '<=', 64.35) & (1, '>', 63.05) & (0, '<=', 0.5) & (5, '>', 4.24))) & (((2, '<=', 57.5) & (6, '>', 2.69) & (4, '<=', 4.28)) | ((2, '<=', 57.15) & (1, '>', 63.05) & (5, '<=', 6.32) & (4, '>', 5.82)) | ((2, '>', 57.15) & (1, '>', 63.05) & (4, '>', 6.38))) & (((2, '>', 57.15) & (1, '>', 63.05) & (0, '<=', 0.44) & (0, '>', 0.3)) | ((4, '<=', 5.17) & (2, '<=', 57.15) & (1, '>', 62.85) & (3, '<=', 827.5)))
#  --------- Get corresponding predicate ---------
# (((table <= 57.05) and (depth > 62.85) and (y > 4.28) and (carat <= 0.67)) or ((table <= 57.05) and (x <= 4.22) and (y <= 4.28) and (z > 2.68)) or ((table > 57.05) and (x > 4.26) and (depth <= 58.15)) or ((table > 57.05) and (x <= 4.26) and (depth > 63.05) and (price <= 644.0)) or ((table <= 57.05) and (x > 4.22) and (y <= 4.28) and (x <= 4.23)) or ((depth <= 64.35) and (table > 57.05) and (x > 4.26) and (depth > 63.05))) and (((depth > 64.35) and (table <= 57.15) and (x <= 4.25)) or ((depth <= 64.35) and (x <= 5.17) and (table <= 57.15) and (depth > 63.05)) or ((table > 57.15) and (depth > 63.05) and (z > 2.6) and (z <= 2.98))) and (((depth > 64.35) and (price <= 520.0)) or ((depth > 64.35) and (z <= 2.66)) or ((depth <= 64.35) and (depth > 63.05) and (carat > 0.5) and (x <= 6.37)) or ((depth <= 64.35) and (depth > 63.05) and (carat <= 0.5) and (y > 4.24))) and (((table <= 57.5) and (z > 2.69) and (x <= 4.28)) or ((table <= 57.15) and (depth > 63.05) and (y <= 6.32) and (x > 5.82)) or ((table > 57.15) and (depth > 63.05) and (x > 6.38))) and (((table > 57.15) and (depth > 63.05) and (carat <= 0.44) and (carat > 0.3)) or ((x <= 5.17) and (table <= 57.15) and (depth > 62.85) and (price <= 827.5)))
#  --------- Calculate precision and recall ---------
# {'precision': 0.01828681424446583, 'recall': 0.8260869565217391, 'f1-score': 0.035781544256120526, 'support': 23}
#  -----------------------------------------
#  -----------------------------------------
#  --------- Combine rules using | (OR) ---------
# ((~A7EB251 & ACFA3C3 & ~A346AF2 & AA1B333) | (~A7EB251 & ~A080468 & A346AF2 & AC6F94E) | (A7EB251 & A9E80D7 & A7D7E75) | (A7EB251 & ~A9E80D7 & A372806 & AA34484) | (~A7EB251 & A080468 & A346AF2 & AECCA3D) | (~A2E9856 & A7EB251 & A9E80D7 & A372806)) | ((A2E9856 & AB70C06 & ~A8D4C7B) | (~A2E9856 & ~AAA91B0 & AB70C06 & A372806) | (~AB70C06 & A372806 & A282C08 & A3C608D)) | ((A2E9856 & ~A2DD9BF) | (A2E9856 & ~A8E7005) | (~A2E9856 & A372806 & ~A58A172 & A63A9E5) | (~A2E9856 & A372806 & A58A172 & ABF7AC5)) | ((A39B6EC & A68B8E0 & A72CB6F) | (AB70C06 & A372806 & A9FCAAE & AC21C76) | (~AB70C06 & A372806 & A3E6400)) | ((~AB70C06 & A372806 & A0D84A3 & A805F86) | (~AAA91B0 & AB70C06 & ACFA3C3 & A1C8E29))
#  --------- Get System readable rule ---------
# (((2, '<=', 57.05) & (1, '>', 62.85) & (5, '>', 4.28) & (0, '<=', 0.67)) | ((2, '<=', 57.05) & (4, '<=', 4.22) & (5, '<=', 4.28) & (6, '>', 2.68)) | ((2, '>', 57.05) & (4, '>', 4.26) & (1, '<=', 58.15)) | ((2, '>', 57.05) & (4, '<=', 4.26) & (1, '>', 63.05) & (3, '<=', 644.0)) | ((2, '<=', 57.05) & (4, '>', 4.22) & (5, '<=', 4.28) & (4, '<=', 4.23)) | ((1, '<=', 64.35) & (2, '>', 57.05) & (4, '>', 4.26) & (1, '>', 63.05))) | (((1, '>', 64.35) & (2, '<=', 57.15) & (4, '<=', 4.25)) | ((1, '<=', 64.35) & (4, '<=', 5.17) & (2, '<=', 57.15) & (1, '>', 63.05)) | ((2, '>', 57.15) & (1, '>', 63.05) & (6, '>', 2.6) & (6, '<=', 2.98))) | (((1, '>', 64.35) & (3, '<=', 520.0)) | ((1, '>', 64.35) & (6, '<=', 2.66)) | ((1, '<=', 64.35) & (1, '>', 63.05) & (0, '>', 0.5) & (4, '<=', 6.37)) | ((1, '<=', 64.35) & (1, '>', 63.05) & (0, '<=', 0.5) & (5, '>', 4.24))) | (((2, '<=', 57.5) & (6, '>', 2.69) & (4, '<=', 4.28)) | ((2, '<=', 57.15) & (1, '>', 63.05) & (5, '<=', 6.32) & (4, '>', 5.82)) | ((2, '>', 57.15) & (1, '>', 63.05) & (4, '>', 6.38))) | (((2, '>', 57.15) & (1, '>', 63.05) & (0, '<=', 0.44) & (0, '>', 0.3)) | ((4, '<=', 5.17) & (2, '<=', 57.15) & (1, '>', 62.85) & (3, '<=', 827.5)))
#  --------- Get corresponding predicate ---------
# (((table <= 57.05) and (depth > 62.85) and (y > 4.28) and (carat <= 0.67)) or ((table <= 57.05) and (x <= 4.22) and (y <= 4.28) and (z > 2.68)) or ((table > 57.05) and (x > 4.26) and (depth <= 58.15)) or ((table > 57.05) and (x <= 4.26) and (depth > 63.05) and (price <= 644.0)) or ((table <= 57.05) and (x > 4.22) and (y <= 4.28) and (x <= 4.23)) or ((depth <= 64.35) and (table > 57.05) and (x > 4.26) and (depth > 63.05))) or (((depth > 64.35) and (table <= 57.15) and (x <= 4.25)) or ((depth <= 64.35) and (x <= 5.17) and (table <= 57.15) and (depth > 63.05)) or ((table > 57.15) and (depth > 63.05) and (z > 2.6) and (z <= 2.98))) or (((depth > 64.35) and (price <= 520.0)) or ((depth > 64.35) and (z <= 2.66)) or ((depth <= 64.35) and (depth > 63.05) and (carat > 0.5) and (x <= 6.37)) or ((depth <= 64.35) and (depth > 63.05) and (carat <= 0.5) and (y > 4.24))) or (((table <= 57.5) and (z > 2.69) and (x <= 4.28)) or ((table <= 57.15) and (depth > 63.05) and (y <= 6.32) and (x > 5.82)) or ((table > 57.15) and (depth > 63.05) and (x > 6.38))) or (((table > 57.15) and (depth > 63.05) and (carat <= 0.44) and (carat > 0.3)) or ((x <= 5.17) and (table <= 57.15) and (depth > 62.85) and (price <= 827.5)))
#  --------- Calculate precision and recall ---------
# {'precision': 0.6333012512030799, 'recall': 0.47067238912732473, 'f1-score': 0.5400082068116537, 'support': 1398}
#  -----------------------------------------
#  -----------------------------------------
#
#
#
#  --------------------------------------- Good ---------------------------------------
#  --------- Rules ---------
# {'(AB70C06 & AE8B367 & ~AEDDFA0) | (A36324E & AB70C06 & AEDDFA0 & ~ACFA3C3) | (AB70C06 & AEDDFA0 & ~A36324E & ~ACFA3C3)', '(A39B6EC & A72CB6F & ~A68B8E0) | (AB70C06 & AC21C76 & AE9B972 & ~A372806) | (AB70C06 & AC21C76 & ~A372806 & ~AE9B972) | (A40FD94 & ~A72CB6F & ~AC21C76 & ~ACFA3C3) | (AB70C06 & ~A40FD94 & ~A72CB6F & ~AC21C76)', '(A346AF2 & ~A080468 & ~A7EB251 & ~AC6F94E) | (AA1B333 & ~A346AF2 & ~A7EB251 & ~ACFA3C3) | (~A346AF2 & ~A372806 & ~A7EB251 & ~AA1B333)', '(A72CB6F & AB70C06 & ~ACFA3C3) | (AB70C06 & AF31A4A & ~A372806 & ~A72CB6F) | (AB70C06 & ~A372806 & ~A72CB6F & ~AF31A4A)', '(A17D61E & A266A02 & ~A372806) | (AB70C06 & AE94C50 & ~A266A02 & ~A372806) | (A266A02 & ~A17D61E & ~A346AF2 & ~A372806)'}
#  --------- Simplified Rules ---------
# {'(A39B6EC & ~A68B8E0 & A72CB6F) | (AB70C06 & ~A372806 & AC21C76) | (AB70C06 & ~A72CB6F & ~AC21C76 & ~A40FD94) | (~ACFA3C3 & ~A72CB6F & ~AC21C76 & A40FD94)', '(AB70C06 & ~ACFA3C3 & A72CB6F) | (AB70C06 & ~A72CB6F & ~A372806)', '(~A7EB251 & ~A080468 & A346AF2 & ~AC6F94E) | (~A7EB251 & ~A372806 & ~A346AF2 & ~AA1B333) | (~A7EB251 & ~ACFA3C3 & ~A346AF2 & AA1B333)', '(~A372806 & ~A346AF2 & A266A02) | (AB70C06 & ~A372806 & ~A266A02 & AE94C50) | (~A372806 & A17D61E & A266A02)', '(AB70C06 & AE8B367 & ~AEDDFA0) | (AB70C06 & ~ACFA3C3 & AEDDFA0)'}
#  --------- Combine rules using & (AND) ---------
# ((A39B6EC & ~A68B8E0 & A72CB6F) | (AB70C06 & ~A372806 & AC21C76) | (AB70C06 & ~A72CB6F & ~AC21C76 & ~A40FD94) | (~ACFA3C3 & ~A72CB6F & ~AC21C76 & A40FD94)) & ((AB70C06 & ~ACFA3C3 & A72CB6F) | (AB70C06 & ~A72CB6F & ~A372806)) & ((~A7EB251 & ~A080468 & A346AF2 & ~AC6F94E) | (~A7EB251 & ~A372806 & ~A346AF2 & ~AA1B333) | (~A7EB251 & ~ACFA3C3 & ~A346AF2 & AA1B333)) & ((~A372806 & ~A346AF2 & A266A02) | (AB70C06 & ~A372806 & ~A266A02 & AE94C50) | (~A372806 & A17D61E & A266A02)) & ((AB70C06 & AE8B367 & ~AEDDFA0) | (AB70C06 & ~ACFA3C3 & AEDDFA0))
#  --------- Get System readable rule ---------
# (((2, '<=', 57.5) & (6, '<=', 2.69) & (4, '<=', 4.28)) | ((2, '<=', 57.15) & (1, '<=', 63.05) & (4, '>', 5.82)) | ((2, '<=', 57.15) & (4, '>', 4.28) & (4, '<=', 5.82) & (0, '<=', 0.63)) | ((1, '<=', 62.85) & (4, '>', 4.28) & (4, '<=', 5.82) & (0, '>', 0.63))) & (((2, '<=', 57.15) & (1, '<=', 62.85) & (4, '<=', 4.28)) | ((2, '<=', 57.15) & (4, '>', 4.28) & (1, '<=', 63.05))) & (((2, '<=', 57.05) & (4, '<=', 4.22) & (5, '<=', 4.28) & (6, '<=', 2.68)) | ((2, '<=', 57.05) & (1, '<=', 63.05) & (5, '>', 4.28) & (0, '>', 0.67)) | ((2, '<=', 57.05) & (1, '<=', 62.85) & (5, '>', 4.28) & (0, '<=', 0.67))) & (((1, '<=', 63.05) & (5, '>', 4.28) & (4, '<=', 6.08)) | ((2, '<=', 57.15) & (1, '<=', 63.05) & (4, '>', 6.08) & (0, '>', 1.01)) | ((1, '<=', 63.05) & (5, '>', 5.45) & (4, '<=', 6.08))) & (((2, '<=', 57.15) & (5, '>', 4.37) & (1, '<=', 60.05)) | ((2, '<=', 57.15) & (1, '<=', 62.85) & (1, '>', 60.05)))
#  --------- Get corresponding predicate ---------
# (((table <= 57.5) and (z <= 2.69) and (x <= 4.28)) or ((table <= 57.15) and (depth <= 63.05) and (x > 5.82)) or ((table <= 57.15) and (x > 4.28) and (x <= 5.82) and (carat <= 0.63)) or ((depth <= 62.85) and (x > 4.28) and (x <= 5.82) and (carat > 0.63))) and (((table <= 57.15) and (depth <= 62.85) and (x <= 4.28)) or ((table <= 57.15) and (x > 4.28) and (depth <= 63.05))) and (((table <= 57.05) and (x <= 4.22) and (y <= 4.28) and (z <= 2.68)) or ((table <= 57.05) and (depth <= 63.05) and (y > 4.28) and (carat > 0.67)) or ((table <= 57.05) and (depth <= 62.85) and (y > 4.28) and (carat <= 0.67))) and (((depth <= 63.05) and (y > 4.28) and (x <= 6.08)) or ((table <= 57.15) and (depth <= 63.05) and (x > 6.08) and (carat > 1.01)) or ((depth <= 63.05) and (y > 5.45) and (x <= 6.08))) and (((table <= 57.15) and (y > 4.37) and (depth <= 60.05)) or ((table <= 57.15) and (depth <= 62.85) and (depth > 60.05)))
#  --------- Calculate precision and recall ---------
# {'precision': 0.8434988179669031, 'recall': 0.8198529411764706, 'f1-score': 0.8315078070379865, 'support': 4352}
#  -----------------------------------------
#  -----------------------------------------
#  --------- Combine rules using | (OR) ---------
# ((A39B6EC & ~A68B8E0 & A72CB6F) | (AB70C06 & ~A372806 & AC21C76) | (AB70C06 & ~A72CB6F & ~AC21C76 & ~A40FD94) | (~ACFA3C3 & ~A72CB6F & ~AC21C76 & A40FD94)) | ((AB70C06 & ~ACFA3C3 & A72CB6F) | (AB70C06 & ~A72CB6F & ~A372806)) | ((~A7EB251 & ~A080468 & A346AF2 & ~AC6F94E) | (~A7EB251 & ~A372806 & ~A346AF2 & ~AA1B333) | (~A7EB251 & ~ACFA3C3 & ~A346AF2 & AA1B333)) | ((~A372806 & ~A346AF2 & A266A02) | (AB70C06 & ~A372806 & ~A266A02 & AE94C50) | (~A372806 & A17D61E & A266A02)) | ((AB70C06 & AE8B367 & ~AEDDFA0) | (AB70C06 & ~ACFA3C3 & AEDDFA0))
#  --------- Get System readable rule ---------
# (((2, '<=', 57.5) & (6, '<=', 2.69) & (4, '<=', 4.28)) | ((2, '<=', 57.15) & (1, '<=', 63.05) & (4, '>', 5.82)) | ((2, '<=', 57.15) & (4, '>', 4.28) & (4, '<=', 5.82) & (0, '<=', 0.63)) | ((1, '<=', 62.85) & (4, '>', 4.28) & (4, '<=', 5.82) & (0, '>', 0.63))) | (((2, '<=', 57.15) & (1, '<=', 62.85) & (4, '<=', 4.28)) | ((2, '<=', 57.15) & (4, '>', 4.28) & (1, '<=', 63.05))) | (((2, '<=', 57.05) & (4, '<=', 4.22) & (5, '<=', 4.28) & (6, '<=', 2.68)) | ((2, '<=', 57.05) & (1, '<=', 63.05) & (5, '>', 4.28) & (0, '>', 0.67)) | ((2, '<=', 57.05) & (1, '<=', 62.85) & (5, '>', 4.28) & (0, '<=', 0.67))) | (((1, '<=', 63.05) & (5, '>', 4.28) & (4, '<=', 6.08)) | ((2, '<=', 57.15) & (1, '<=', 63.05) & (4, '>', 6.08) & (0, '>', 1.01)) | ((1, '<=', 63.05) & (5, '>', 5.45) & (4, '<=', 6.08))) | (((2, '<=', 57.15) & (5, '>', 4.37) & (1, '<=', 60.05)) | ((2, '<=', 57.15) & (1, '<=', 62.85) & (1, '>', 60.05)))
#  --------- Get corresponding predicate ---------
# (((table <= 57.5) and (z <= 2.69) and (x <= 4.28)) or ((table <= 57.15) and (depth <= 63.05) and (x > 5.82)) or ((table <= 57.15) and (x > 4.28) and (x <= 5.82) and (carat <= 0.63)) or ((depth <= 62.85) and (x > 4.28) and (x <= 5.82) and (carat > 0.63))) or (((table <= 57.15) and (depth <= 62.85) and (x <= 4.28)) or ((table <= 57.15) and (x > 4.28) and (depth <= 63.05))) or (((table <= 57.05) and (x <= 4.22) and (y <= 4.28) and (z <= 2.68)) or ((table <= 57.05) and (depth <= 63.05) and (y > 4.28) and (carat > 0.67)) or ((table <= 57.05) and (depth <= 62.85) and (y > 4.28) and (carat <= 0.67))) or (((depth <= 63.05) and (y > 4.28) and (x <= 6.08)) or ((table <= 57.15) and (depth <= 63.05) and (x > 6.08) and (carat > 1.01)) or ((depth <= 63.05) and (y > 5.45) and (x <= 6.08))) or (((table <= 57.15) and (y > 4.37) and (depth <= 60.05)) or ((table <= 57.15) and (depth <= 62.85) and (depth > 60.05)))
#  --------- Calculate precision and recall ---------
# {'precision': 0.966193853427896, 'recall': 0.5568119891008174, 'f1-score': 0.7064822817631806, 'support': 7340}
#  -----------------------------------------
#  -----------------------------------------
#
#
#
#  --------------------------------------- Very Good ---------------------------------------
#  --------- Rules ---------
# {'(A080D08 & A7EB251 & ~A9E80D7 & ~AA34484) | (A7EB251 & A9E80D7 & ~A372806 & ~A7D7E75)', '(A6D29AE & A72CB6F & ~A39B6EC) | (A3E6400 & ~A372806 & ~AB70C06) | (A8BF9A7 & AC21C76 & ~A3E6400 & ~AB70C06) | (~A40FD94 & ~A72CB6F & ~AB70C06 & ~AC21C76)', '(A266A02 & A346AF2 & A9E80D7 & ~A372806) | (AD6E8BC & ~A266A02 & ~A372806 & ~AE94C50) | (AE94C50 & ~A266A02 & ~A372806 & ~AB70C06)', '(A805F86 & ~A282C08 & ~AB70C06) | (A282C08 & A3C608D & ~A372806 & ~AB70C06) | (A3E6400 & AB25A8F & ~A3C608D & ~AB70C06) | (A115C2C & ~A3C608D & ~AB25A8F & ~AB70C06) | (AB25A8F & ~A3C608D & ~A3E6400 & ~AB70C06) | (~A115C2C & ~A3C608D & ~AB25A8F & ~AB70C06)', '(A391BD3 & ~A805F86 & ~AB70C06) | (A0D84A3 & A805F86 & ~A372806 & ~AB70C06) | (A3E6400 & A8F43D3 & ~A0D84A3 & ~AB70C06) | (A3E6400 & ~A0D84A3 & ~A8F43D3 & ~AB70C06) | (A66C939 & ~A0D84A3 & ~A3E6400 & ~AB70C06)'}
#  --------- Simplified Rules ---------
# {'(~AB70C06 & A3E6400 & ~A0D84A3) | (~AB70C06 & ~A0D84A3 & A66C939) | (~AB70C06 & ~A372806 & A0D84A3 & A805F86) | (~AB70C06 & ~A805F86 & A391BD3)', '(A7EB251 & ~A9E80D7 & ~AA34484 & A080D08) | (A7EB251 & A9E80D7 & ~A372806 & ~A7D7E75)', '(~AB70C06 & A805F86 & ~A282C08) | (~AB70C06 & ~A372806 & A282C08) | (~AB70C06 & ~A3C608D)', '(A9E80D7 & ~A372806 & A346AF2 & A266A02) | (~A372806 & ~A266A02 & ~AE94C50 & AD6E8BC) | (~AB70C06 & ~A372806 & ~A266A02 & AE94C50)', '(~A39B6EC & A72CB6F & A6D29AE) | (~AB70C06 & ~A3E6400 & AC21C76 & A8BF9A7) | (~AB70C06 & ~A72CB6F & ~AC21C76 & ~A40FD94) | (~AB70C06 & ~A372806 & A3E6400)'}
#  --------- Combine rules using & (AND) ---------
# ((~AB70C06 & A3E6400 & ~A0D84A3) | (~AB70C06 & ~A0D84A3 & A66C939) | (~AB70C06 & ~A372806 & A0D84A3 & A805F86) | (~AB70C06 & ~A805F86 & A391BD3)) & ((A7EB251 & ~A9E80D7 & ~AA34484 & A080D08) | (A7EB251 & A9E80D7 & ~A372806 & ~A7D7E75)) & ((~AB70C06 & A805F86 & ~A282C08) | (~AB70C06 & ~A372806 & A282C08) | (~AB70C06 & ~A3C608D)) & ((A9E80D7 & ~A372806 & A346AF2 & A266A02) | (~A372806 & ~A266A02 & ~AE94C50 & AD6E8BC) | (~AB70C06 & ~A372806 & ~A266A02 & AE94C50)) & ((~A39B6EC & A72CB6F & A6D29AE) | (~AB70C06 & ~A3E6400 & AC21C76 & A8BF9A7) | (~AB70C06 & ~A72CB6F & ~AC21C76 & ~A40FD94) | (~AB70C06 & ~A372806 & A3E6400))
#  --------- Get System readable rule ---------
# (((2, '>', 57.15) & (4, '>', 6.38) & (0, '>', 0.44)) | ((2, '>', 57.15) & (0, '>', 0.44) & (5, '<=', 6.34)) | ((2, '>', 57.15) & (1, '<=', 63.05) & (0, '<=', 0.44) & (0, '>', 0.3)) | ((2, '>', 57.15) & (0, '<=', 0.3) & (3, '>', 666.0))) & (((2, '>', 57.05) & (4, '<=', 4.26) & (3, '>', 644.0) & (5, '<=', 4.17)) | ((2, '>', 57.05) & (4, '>', 4.26) & (1, '<=', 63.05) & (1, '>', 58.15))) & (((2, '>', 57.15) & (0, '>', 0.3) & (6, '<=', 2.6)) | ((2, '>', 57.15) & (1, '<=', 63.05) & (6, '>', 2.6)) | ((2, '>', 57.15) & (6, '>', 2.98))) & (((4, '>', 4.26) & (1, '<=', 63.05) & (5, '<=', 4.28) & (4, '<=', 6.08)) | ((1, '<=', 63.05) & (4, '>', 6.08) & (0, '<=', 1.01) & (5, '<=', 6.56)) | ((2, '>', 57.15) & (1, '<=', 63.05) & (4, '>', 6.08) & (0, '>', 1.01))) & (((2, '>', 57.5) & (4, '<=', 4.28) & (3, '>', 628.5)) | ((2, '>', 57.15) & (4, '<=', 6.38) & (4, '>', 5.82) & (0, '<=', 0.83)) | ((2, '>', 57.15) & (4, '>', 4.28) & (4, '<=', 5.82) & (0, '<=', 0.63)) | ((2, '>', 57.15) & (1, '<=', 63.05) & (4, '>', 6.38)))
#  --------- Get corresponding predicate ---------
# (((table > 57.15) and (x > 6.38) and (carat > 0.44)) or ((table > 57.15) and (carat > 0.44) and (y <= 6.34)) or ((table > 57.15) and (depth <= 63.05) and (carat <= 0.44) and (carat > 0.3)) or ((table > 57.15) and (carat <= 0.3) and (price > 666.0))) and (((table > 57.05) and (x <= 4.26) and (price > 644.0) and (y <= 4.17)) or ((table > 57.05) and (x > 4.26) and (depth <= 63.05) and (depth > 58.15))) and (((table > 57.15) and (carat > 0.3) and (z <= 2.6)) or ((table > 57.15) and (depth <= 63.05) and (z > 2.6)) or ((table > 57.15) and (z > 2.98))) and (((x > 4.26) and (depth <= 63.05) and (y <= 4.28) and (x <= 6.08)) or ((depth <= 63.05) and (x > 6.08) and (carat <= 1.01) and (y <= 6.56)) or ((table > 57.15) and (depth <= 63.05) and (x > 6.08) and (carat > 1.01))) and (((table > 57.5) and (x <= 4.28) and (price > 628.5)) or ((table > 57.15) and (x <= 6.38) and (x > 5.82) and (carat <= 0.83)) or ((table > 57.15) and (x > 4.28) and (x <= 5.82) and (carat <= 0.63)) or ((table > 57.15) and (depth <= 63.05) and (x > 6.38)))
#  --------- Calculate precision and recall ---------
# {'precision': 0.3855595667870036, 'recall': 0.651219512195122, 'f1-score': 0.48435374149659866, 'support': 1640}
#  -----------------------------------------
#  -----------------------------------------
#  --------- Combine rules using | (OR) ---------
# ((~AB70C06 & A3E6400 & ~A0D84A3) | (~AB70C06 & ~A0D84A3 & A66C939) | (~AB70C06 & ~A372806 & A0D84A3 & A805F86) | (~AB70C06 & ~A805F86 & A391BD3)) | ((A7EB251 & ~A9E80D7 & ~AA34484 & A080D08) | (A7EB251 & A9E80D7 & ~A372806 & ~A7D7E75)) | ((~AB70C06 & A805F86 & ~A282C08) | (~AB70C06 & ~A372806 & A282C08) | (~AB70C06 & ~A3C608D)) | ((A9E80D7 & ~A372806 & A346AF2 & A266A02) | (~A372806 & ~A266A02 & ~AE94C50 & AD6E8BC) | (~AB70C06 & ~A372806 & ~A266A02 & AE94C50)) | ((~A39B6EC & A72CB6F & A6D29AE) | (~AB70C06 & ~A3E6400 & AC21C76 & A8BF9A7) | (~AB70C06 & ~A72CB6F & ~AC21C76 & ~A40FD94) | (~AB70C06 & ~A372806 & A3E6400))
#  --------- Get System readable rule ---------
# (((2, '>', 57.15) & (4, '>', 6.38) & (0, '>', 0.44)) | ((2, '>', 57.15) & (0, '>', 0.44) & (5, '<=', 6.34)) | ((2, '>', 57.15) & (1, '<=', 63.05) & (0, '<=', 0.44) & (0, '>', 0.3)) | ((2, '>', 57.15) & (0, '<=', 0.3) & (3, '>', 666.0))) | (((2, '>', 57.05) & (4, '<=', 4.26) & (3, '>', 644.0) & (5, '<=', 4.17)) | ((2, '>', 57.05) & (4, '>', 4.26) & (1, '<=', 63.05) & (1, '>', 58.15))) | (((2, '>', 57.15) & (0, '>', 0.3) & (6, '<=', 2.6)) | ((2, '>', 57.15) & (1, '<=', 63.05) & (6, '>', 2.6)) | ((2, '>', 57.15) & (6, '>', 2.98))) | (((4, '>', 4.26) & (1, '<=', 63.05) & (5, '<=', 4.28) & (4, '<=', 6.08)) | ((1, '<=', 63.05) & (4, '>', 6.08) & (0, '<=', 1.01) & (5, '<=', 6.56)) | ((2, '>', 57.15) & (1, '<=', 63.05) & (4, '>', 6.08) & (0, '>', 1.01))) | (((2, '>', 57.5) & (4, '<=', 4.28) & (3, '>', 628.5)) | ((2, '>', 57.15) & (4, '<=', 6.38) & (4, '>', 5.82) & (0, '<=', 0.83)) | ((2, '>', 57.15) & (4, '>', 4.28) & (4, '<=', 5.82) & (0, '<=', 0.63)) | ((2, '>', 57.15) & (1, '<=', 63.05) & (4, '>', 6.38)))
#  --------- Get corresponding predicate ---------
# (((table > 57.15) and (x > 6.38) and (carat > 0.44)) or ((table > 57.15) and (carat > 0.44) and (y <= 6.34)) or ((table > 57.15) and (depth <= 63.05) and (carat <= 0.44) and (carat > 0.3)) or ((table > 57.15) and (carat <= 0.3) and (price > 666.0))) or (((table > 57.05) and (x <= 4.26) and (price > 644.0) and (y <= 4.17)) or ((table > 57.05) and (x > 4.26) and (depth <= 63.05) and (depth > 58.15))) or (((table > 57.15) and (carat > 0.3) and (z <= 2.6)) or ((table > 57.15) and (depth <= 63.05) and (z > 2.6)) or ((table > 57.15) and (z > 2.98))) or (((x > 4.26) and (depth <= 63.05) and (y <= 4.28) and (x <= 6.08)) or ((depth <= 63.05) and (x > 6.08) and (carat <= 1.01) and (y <= 6.56)) or ((table > 57.15) and (depth <= 63.05) and (x > 6.08) and (carat > 1.01))) or (((table > 57.5) and (x <= 4.28) and (price > 628.5)) or ((table > 57.15) and (x <= 6.38) and (x > 5.82) and (carat <= 0.83)) or ((table > 57.15) and (x > 4.28) and (x <= 5.82) and (carat <= 0.63)) or ((table > 57.15) and (depth <= 63.05) and (x > 6.38)))
#  --------- Calculate precision and recall ---------
# {'precision': 0.8859205776173286, 'recall': 0.4783625730994152, 'f1-score': 0.6212658227848101, 'support': 5130}
#  -----------------------------------------
#  -----------------------------------------
#
#
#
#  --------------------------------------- Fair ---------------------------------------
#  --------- Rules ---------
# {'(A372806 & AAA91B0 & AB70C06 & ~A2E9856) | (A72CB6F & AB70C06 & ACFA3C3 & ~A372806) | (~A282C08 & ~A805F86 & ~AB70C06)', '(A72CB6F & ~A39B6EC & ~A6D29AE) | (A372806 & AB70C06 & AC21C76 & ~A9FCAAE) | (A40FD94 & ACFA3C3 & ~A72CB6F & ~AC21C76) | (AC21C76 & ~A3E6400 & ~A8BF9A7 & ~AB70C06)', '(AB70C06 & ~AE8B367 & ~AEDDFA0) | (AAA91B0 & AB70C06 & ACFA3C3 & ~A62EE0E) | (~A391BD3 & ~A805F86 & ~AB70C06) | (AB70C06 & ACFA3C3 & ~A1C8E29 & ~AAA91B0) | (~A0D84A3 & ~A3E6400 & ~A66C939 & ~AB70C06)', '(A346AF2 & ~A372806 & ~A9E80D7) | (A372806 & A58A172 & ~A2E9856 & ~ABF7AC5) | (A372806 & ~A2E9856 & ~A58A172 & ~A63A9E5) | (~A266A02 & ~A372806 & ~AD6E8BC & ~AE94C50)', '(A346AF2 & ~A7EB251 & ~AECCA3D) | (A7EB251 & AA34484 & ~A372806 & ~A9E80D7) | (A372806 & ~A346AF2 & ~A7EB251 & ~AA1B333) | (A7EB251 & ~A080D08 & ~A9E80D7 & ~AA34484)'}
#  --------- Simplified Rules ---------
# {'(A7EB251 & ~A9E80D7 & ~AA34484 & ~A080D08) | (~A7EB251 & A372806 & ~A346AF2 & ~AA1B333) | (~A7EB251 & A346AF2 & ~AECCA3D) | (A7EB251 & ~A9E80D7 & ~A372806 & AA34484)', '(~A372806 & ~A266A02 & ~AE94C50 & ~AD6E8BC) | (~A2E9856 & A372806 & A58A172 & ~ABF7AC5) | (~A2E9856 & A372806 & ~A58A172 & ~A63A9E5) | (~A9E80D7 & ~A372806 & A346AF2)', '(~AB70C06 & ~A3E6400 & ~A0D84A3 & ~A66C939) | (AB70C06 & ~AE8B367 & ~AEDDFA0) | (~AAA91B0 & AB70C06 & ACFA3C3 & ~A1C8E29) | (~A62EE0E & AAA91B0 & AB70C06 & ACFA3C3) | (~AB70C06 & ~A805F86 & ~A391BD3)', '(~AB70C06 & ~A805F86 & ~A282C08) | (AB70C06 & ACFA3C3 & A72CB6F & ~A372806) | (~A2E9856 & AAA91B0 & AB70C06 & A372806)', '(~A39B6EC & A72CB6F & ~A6D29AE) | (~AB70C06 & ~A3E6400 & AC21C76 & ~A8BF9A7) | (ACFA3C3 & ~A72CB6F & ~AC21C76 & A40FD94) | (AB70C06 & A372806 & ~A9FCAAE & AC21C76)'}
#  --------- Combine rules using & (AND) ---------
# ((A7EB251 & ~A9E80D7 & ~AA34484 & ~A080D08) | (~A7EB251 & A372806 & ~A346AF2 & ~AA1B333) | (~A7EB251 & A346AF2 & ~AECCA3D) | (A7EB251 & ~A9E80D7 & ~A372806 & AA34484)) & ((~A372806 & ~A266A02 & ~AE94C50 & ~AD6E8BC) | (~A2E9856 & A372806 & A58A172 & ~ABF7AC5) | (~A2E9856 & A372806 & ~A58A172 & ~A63A9E5) | (~A9E80D7 & ~A372806 & A346AF2)) & ((~AB70C06 & ~A3E6400 & ~A0D84A3 & ~A66C939) | (AB70C06 & ~AE8B367 & ~AEDDFA0) | (~AAA91B0 & AB70C06 & ACFA3C3 & ~A1C8E29) | (~A62EE0E & AAA91B0 & AB70C06 & ACFA3C3) | (~AB70C06 & ~A805F86 & ~A391BD3)) & ((~AB70C06 & ~A805F86 & ~A282C08) | (AB70C06 & ACFA3C3 & A72CB6F & ~A372806) | (~A2E9856 & AAA91B0 & AB70C06 & A372806)) & ((~A39B6EC & A72CB6F & ~A6D29AE) | (~AB70C06 & ~A3E6400 & AC21C76 & ~A8BF9A7) | (ACFA3C3 & ~A72CB6F & ~AC21C76 & A40FD94) | (AB70C06 & A372806 & ~A9FCAAE & AC21C76))
#  --------- Get System readable rule ---------
# (((2, '>', 57.05) & (4, '<=', 4.26) & (3, '>', 644.0) & (5, '>', 4.17)) | ((2, '<=', 57.05) & (1, '>', 63.05) & (5, '>', 4.28) & (0, '>', 0.67)) | ((2, '<=', 57.05) & (5, '<=', 4.28) & (4, '>', 4.23)) | ((2, '>', 57.05) & (4, '<=', 4.26) & (1, '<=', 63.05) & (3, '<=', 644.0))) & (((1, '<=', 63.05) & (4, '>', 6.08) & (0, '<=', 1.01) & (5, '>', 6.56)) | ((1, '<=', 64.35) & (1, '>', 63.05) & (0, '<=', 0.5) & (5, '<=', 4.24)) | ((1, '<=', 64.35) & (1, '>', 63.05) & (0, '>', 0.5) & (4, '>', 6.37)) | ((4, '<=', 4.26) & (1, '<=', 63.05) & (5, '<=', 4.28))) & (((2, '>', 57.15) & (4, '<=', 6.38) & (0, '>', 0.44) & (5, '>', 6.34)) | ((2, '<=', 57.15) & (5, '<=', 4.37) & (1, '<=', 60.05)) | ((4, '<=', 5.17) & (2, '<=', 57.15) & (1, '>', 62.85) & (3, '>', 827.5)) | ((0, '<=', 1.79) & (4, '>', 5.17) & (2, '<=', 57.15) & (1, '>', 62.85)) | ((2, '>', 57.15) & (0, '<=', 0.3) & (3, '<=', 666.0))) & (((2, '>', 57.15) & (0, '<=', 0.3) & (6, '<=', 2.6)) | ((2, '<=', 57.15) & (1, '>', 62.85) & (4, '<=', 4.28) & (1, '<=', 63.05)) | ((1, '<=', 64.35) & (4, '>', 5.17) & (2, '<=', 57.15) & (1, '>', 63.05))) & (((2, '>', 57.5) & (4, '<=', 4.28) & (3, '<=', 628.5)) | ((2, '>', 57.15) & (4, '<=', 6.38) & (4, '>', 5.82) & (0, '>', 0.83)) | ((1, '>', 62.85) & (4, '>', 4.28) & (4, '<=', 5.82) & (0, '>', 0.63)) | ((2, '<=', 57.15) & (1, '>', 63.05) & (5, '>', 6.32) & (4, '>', 5.82)))
#  --------- Get corresponding predicate ---------
# (((table > 57.05) and (x <= 4.26) and (price > 644.0) and (y > 4.17)) or ((table <= 57.05) and (depth > 63.05) and (y > 4.28) and (carat > 0.67)) or ((table <= 57.05) and (y <= 4.28) and (x > 4.23)) or ((table > 57.05) and (x <= 4.26) and (depth <= 63.05) and (price <= 644.0))) and (((depth <= 63.05) and (x > 6.08) and (carat <= 1.01) and (y > 6.56)) or ((depth <= 64.35) and (depth > 63.05) and (carat <= 0.5) and (y <= 4.24)) or ((depth <= 64.35) and (depth > 63.05) and (carat > 0.5) and (x > 6.37)) or ((x <= 4.26) and (depth <= 63.05) and (y <= 4.28))) and (((table > 57.15) and (x <= 6.38) and (carat > 0.44) and (y > 6.34)) or ((table <= 57.15) and (y <= 4.37) and (depth <= 60.05)) or ((x <= 5.17) and (table <= 57.15) and (depth > 62.85) and (price > 827.5)) or ((carat <= 1.79) and (x > 5.17) and (table <= 57.15) and (depth > 62.85)) or ((table > 57.15) and (carat <= 0.3) and (price <= 666.0))) and (((table > 57.15) and (carat <= 0.3) and (z <= 2.6)) or ((table <= 57.15) and (depth > 62.85) and (x <= 4.28) and (depth <= 63.05)) or ((depth <= 64.35) and (x > 5.17) and (table <= 57.15) and (depth > 63.05))) and (((table > 57.5) and (x <= 4.28) and (price <= 628.5)) or ((table > 57.15) and (x <= 6.38) and (x > 5.82) and (carat > 0.83)) or ((depth > 62.85) and (x > 4.28) and (x <= 5.82) and (carat > 0.63)) or ((table <= 57.15) and (depth > 63.05) and (y > 6.32) and (x > 5.82)))
#  --------- Calculate precision and recall ---------
# {'precision': 0.06144329896907216, 'recall': 0.6056910569105691, 'f1-score': 0.11156870086110071, 'support': 246}
#  -----------------------------------------
#  -----------------------------------------
#  --------- Combine rules using | (OR) ---------
# ((A7EB251 & ~A9E80D7 & ~AA34484 & ~A080D08) | (~A7EB251 & A372806 & ~A346AF2 & ~AA1B333) | (~A7EB251 & A346AF2 & ~AECCA3D) | (A7EB251 & ~A9E80D7 & ~A372806 & AA34484)) | ((~A372806 & ~A266A02 & ~AE94C50 & ~AD6E8BC) | (~A2E9856 & A372806 & A58A172 & ~ABF7AC5) | (~A2E9856 & A372806 & ~A58A172 & ~A63A9E5) | (~A9E80D7 & ~A372806 & A346AF2)) | ((~AB70C06 & ~A3E6400 & ~A0D84A3 & ~A66C939) | (AB70C06 & ~AE8B367 & ~AEDDFA0) | (~AAA91B0 & AB70C06 & ACFA3C3 & ~A1C8E29) | (~A62EE0E & AAA91B0 & AB70C06 & ACFA3C3) | (~AB70C06 & ~A805F86 & ~A391BD3)) | ((~AB70C06 & ~A805F86 & ~A282C08) | (AB70C06 & ACFA3C3 & A72CB6F & ~A372806) | (~A2E9856 & AAA91B0 & AB70C06 & A372806)) | ((~A39B6EC & A72CB6F & ~A6D29AE) | (~AB70C06 & ~A3E6400 & AC21C76 & ~A8BF9A7) | (ACFA3C3 & ~A72CB6F & ~AC21C76 & A40FD94) | (AB70C06 & A372806 & ~A9FCAAE & AC21C76))
#  --------- Get System readable rule ---------
# (((2, '>', 57.05) & (4, '<=', 4.26) & (3, '>', 644.0) & (5, '>', 4.17)) | ((2, '<=', 57.05) & (1, '>', 63.05) & (5, '>', 4.28) & (0, '>', 0.67)) | ((2, '<=', 57.05) & (5, '<=', 4.28) & (4, '>', 4.23)) | ((2, '>', 57.05) & (4, '<=', 4.26) & (1, '<=', 63.05) & (3, '<=', 644.0))) | (((1, '<=', 63.05) & (4, '>', 6.08) & (0, '<=', 1.01) & (5, '>', 6.56)) | ((1, '<=', 64.35) & (1, '>', 63.05) & (0, '<=', 0.5) & (5, '<=', 4.24)) | ((1, '<=', 64.35) & (1, '>', 63.05) & (0, '>', 0.5) & (4, '>', 6.37)) | ((4, '<=', 4.26) & (1, '<=', 63.05) & (5, '<=', 4.28))) | (((2, '>', 57.15) & (4, '<=', 6.38) & (0, '>', 0.44) & (5, '>', 6.34)) | ((2, '<=', 57.15) & (5, '<=', 4.37) & (1, '<=', 60.05)) | ((4, '<=', 5.17) & (2, '<=', 57.15) & (1, '>', 62.85) & (3, '>', 827.5)) | ((0, '<=', 1.79) & (4, '>', 5.17) & (2, '<=', 57.15) & (1, '>', 62.85)) | ((2, '>', 57.15) & (0, '<=', 0.3) & (3, '<=', 666.0))) | (((2, '>', 57.15) & (0, '<=', 0.3) & (6, '<=', 2.6)) | ((2, '<=', 57.15) & (1, '>', 62.85) & (4, '<=', 4.28) & (1, '<=', 63.05)) | ((1, '<=', 64.35) & (4, '>', 5.17) & (2, '<=', 57.15) & (1, '>', 63.05))) | (((2, '>', 57.5) & (4, '<=', 4.28) & (3, '<=', 628.5)) | ((2, '>', 57.15) & (4, '<=', 6.38) & (4, '>', 5.82) & (0, '>', 0.83)) | ((1, '>', 62.85) & (4, '>', 4.28) & (4, '<=', 5.82) & (0, '>', 0.63)) | ((2, '<=', 57.15) & (1, '>', 63.05) & (5, '>', 6.32) & (4, '>', 5.82)))
#  --------- Get corresponding predicate ---------
# (((table > 57.05) and (x <= 4.26) and (price > 644.0) and (y > 4.17)) or ((table <= 57.05) and (depth > 63.05) and (y > 4.28) and (carat > 0.67)) or ((table <= 57.05) and (y <= 4.28) and (x > 4.23)) or ((table > 57.05) and (x <= 4.26) and (depth <= 63.05) and (price <= 644.0))) or (((depth <= 63.05) and (x > 6.08) and (carat <= 1.01) and (y > 6.56)) or ((depth <= 64.35) and (depth > 63.05) and (carat <= 0.5) and (y <= 4.24)) or ((depth <= 64.35) and (depth > 63.05) and (carat > 0.5) and (x > 6.37)) or ((x <= 4.26) and (depth <= 63.05) and (y <= 4.28))) or (((table > 57.15) and (x <= 6.38) and (carat > 0.44) and (y > 6.34)) or ((table <= 57.15) and (y <= 4.37) and (depth <= 60.05)) or ((x <= 5.17) and (table <= 57.15) and (depth > 62.85) and (price > 827.5)) or ((carat <= 1.79) and (x > 5.17) and (table <= 57.15) and (depth > 62.85)) or ((table > 57.15) and (carat <= 0.3) and (price <= 666.0))) or (((table > 57.15) and (carat <= 0.3) and (z <= 2.6)) or ((table <= 57.15) and (depth > 62.85) and (x <= 4.28) and (depth <= 63.05)) or ((depth <= 64.35) and (x > 5.17) and (table <= 57.15) and (depth > 63.05))) or (((table > 57.5) and (x <= 4.28) and (price <= 628.5)) or ((table > 57.15) and (x <= 6.38) and (x > 5.82) and (carat > 0.83)) or ((depth > 62.85) and (x > 4.28) and (x <= 5.82) and (carat > 0.63)) or ((table <= 57.15) and (depth > 63.05) and (y > 6.32) and (x > 5.82)))
#  --------- Calculate precision and recall ---------
# {'precision': 0.36082474226804123, 'recall': 0.3902765388046387, 'f1-score': 0.37497321619884294, 'support': 2242}
#  -----------------------------------------
#  -----------------------------------------

# %%
rule_dict = {}
var_dict = {}

rules, s_rules = combine_forest_rules(rfclf, "Ideal", rule_dict, var_dict)
rules
# Out:
# {'A0422F6 & A0A243A & AABA68F & AC8140A',
#  'A0BAB7C & A357E83 & AB8BD49',
#  'A0BAB7C & A525C94 & AC8140A',
#  'A0BAB7C & A7FC805 & A88A0B6'}

# %%
s_rules
# Out:
# {'A0422F6 & A0A243A & AABA68F & AC8140A',
#  'A0BAB7C & A357E83 & AB8BD49',
#  'A0BAB7C & A7FC805 & A88A0B6',
#  'A0BAB7C & AC8140A & A525C94'}

# %%
s = combine_rule_using_and(s_rules, '&')
s
# Out:
# '(A0422F6 & A0A243A & AABA68F & AC8140A) & (A0BAB7C & A357E83 & AB8BD49) & (A0BAB7C & AC8140A & A525C94) & (A0BAB7C & A7FC805 & A88A0B6)'

# %%
sys_readable_rule = print_final_rule(s)
sys_readable_rule
# Out:
# "((4, '>', 5.17) & (0, '>', 1.79) & (1, '>', 62.85) & (2, '<=', 57.15)) & ((1, '>', 64.35) & (6, '>', 2.66) & (3, '>', 520.0)) & ((1, '>', 64.35) & (2, '<=', 57.15) & (4, '>', 4.25)) & ((1, '>', 64.35) & (2, '>', 57.05) & (4, '>', 4.26))"

# %%
redundant_rules_set, composed_rules_set = split_rules(sys_readable_rule)

# %%
redundant_rules_set
# Out:
# set()

# %%
hum_readable_rule = get_valid_predicate(sys_readable_rule)

# %%
hum_readable_rule
# Out:
# '((x > 5.17) and (carat > 1.79) and (depth > 62.85) and (table <= 57.15)) and ((depth > 64.35) and (z > 2.66) and (price > 520.0)) and ((depth > 64.35) and (table <= 57.15) and (x > 4.25)) and ((depth > 64.35) and (table > 57.05) and (x > 4.26))'

# %%
compute_final_rule_accuracy(0, hum_readable_rule)
# Out:
# {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}

# %%
visualize_decision_boundaries(hum_readable_rule, 0, 1)

# %% [markdown]
# ### Poznamky
#
# - Pre velmi dlhe pravidlo jednotliveho stromu pospajane OR-om, nemoz redukovat pouzijuc normalny simplify_logic, ale pouzijuc espresso, ktory nie vzdy zredukuje vyraz
# - Nemoz pouzit to_dnf/to_cnf, vyraz sa nezjedoduchsi (prilis vela atributov)
# - Ked finalne pravidlo ktore zoberieme z celemo forestu, skombinujeme AND-om, precision/recall = 0. Ked OR-om, tak to sa este da

# %% [markdown]
# ------
# # Podla feature_contributions, vyberieme iba najlepsie atributy
#
# Snazime sa zredukovat z atributov lesa, aby sme videli ci vygeneruje viac zmysluplne pravidla a zlepsi sa precision/recall pri AND-e.

# %%
rfclf.feature_importances_
# Out:
# array([0.01703458, 0.32794618, 0.57832037, 0.00382928, 0.04741516,
#        0.01795995, 0.00749448])

# %%
data_.columns.values
# Out:
# array(['carat', 'depth', 'table', 'price', 'x', 'y', 'z'], dtype=object)

# %%
df = data_.copy()

# %%
df.pop('carat')
df.pop('price')
df.pop('x')
df.pop('y')
df.pop('z')
# Out:
# 0        2.43
# 1        2.31
# 2        2.31
# 3        2.63
# 4        2.75
# 5        2.48
# 6        2.47
# 7        2.53
# 8        2.49
# 9        2.39
# 10       2.73
# 11       2.46
# 12       2.33
# 13       2.71
# 14       2.27
# 15       2.68
# 16       2.68
# 17       2.70
# 18       2.71
# 19       2.66
# 20       2.71
# 21       2.48
# 22       2.41
# 23       2.62
# 24       2.59
# 25       2.41
# 26       2.47
# 27       2.67
# 28       2.40
# 29       2.42
#          ...
# 53910    3.48
# 53911    3.23
# 53912    3.36
# 53913    3.74
# 53914    3.77
# 53915    3.63
# 53916    3.61
# 53917    3.86
# 53918    3.49
# 53919    3.66
# 53920    3.49
# 53921    3.53
# 53922    3.55
# 53923    3.57
# 53924    3.59
# 53925    3.67
# 53926    3.54
# 53927    3.54
# 53928    3.68
# 53929    3.53
# 53930    3.49
# 53931    3.43
# 53932    3.47
# 53933    3.49
# 53934    3.58
# 53935    3.50
# 53936    3.61
# 53937    3.56
# 53938    3.74
# 53939    3.64
# Name: z, Length: 53940, dtype: float64

# %%
len(Y)
# Out:
# 10788

# %%
from sklearn import model_selection

array = data.values
Y = data['cut'].values
X = df.values
validation_size = 0.20
seed = 7
X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(X, Y, test_size=validation_size, random_state=seed)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y_train = le.fit_transform(Y_train)
Y_validation = le.fit_transform(Y_validation)

# %%
from sklearn.ensemble import RandomForestClassifier

rfclf = RandomForestClassifier(n_estimators=5, max_depth=4)
rfclf.fit(X_train, Y_train)

pred = rfclf.predict(X_validation)

# %%
def combine_forest_rules(rf_model, class_name, r_dict, v_dict):
    final_rule = set()
    simplified_final_rule = set()
    for estimator in rf_model.estimators_:
    
        rules = set()
        get_paths_for(class_name, estimator.tree_, 0, [], rules, '<=')
        
        rules = redundancy_condition_removal(rules)
        tree_rule = sympify(create_big_or_rule(rules), evaluate=False)
        
        final_rule.add(str(tree_rule))
        simplified_final_rule.add(str(simplify_logic(tree_rule)))        
        
    return final_rule, simplified_final_rule

# %%
rule_dict = {}
var_dict = {}

rules, s_rules = combine_forest_rules(rfclf, "Fair", rule_dict, var_dict)
rules
# Out:
# {'(A0CCCF2 & A519FF7 & AC91BD0) | (A051928 & AD67095 & ~AC91BD0) | (A538CD8 & ~A224644 & ~AC91BD0)',
#  '(A430970 & AC91BD0) | (A0CCCF2 & ~A430970) | (A224644 & A538CD8 & ~AC91BD0)',
#  '(A430970 & AC91BD0) | (A0CCCF2 & ~A430970) | (A538CD8 & A933EC2 & AEDF6B1 & ~AC91BD0)',
#  '(A6B7121 & AC91BD0) | (A0CCCF2 & ~A6B7121)',
#  '(A7B34CF & A933EC2) | (A0CCCF2 & A933EC2 & AC91BD0) | (A0EF1D6 & A538CD8 & A933EC2 & ~AC91BD0)'}

# %%
s_rules
# Out:
# {'(A0CCCF2 | ~AC91BD0) & (A519FF7 | ~AC91BD0) & (A051928 | A538CD8 | AC91BD0) & (A538CD8 | AC91BD0 | AD67095) & (A051928 | AC91BD0 | ~A224644) & (AC91BD0 | AD67095 | ~A224644)',
#  '(A430970 & AC91BD0) | (A0CCCF2 & ~A430970) | (A224644 & A538CD8 & ~AC91BD0)',
#  '(A430970 & AC91BD0) | (A0CCCF2 & ~A430970) | (A538CD8 & A933EC2 & AEDF6B1 & ~AC91BD0)',
#  '(A6B7121 & AC91BD0) | (A0CCCF2 & ~A6B7121)',
#  'A933EC2 & (A0EF1D6 | A7B34CF | AC91BD0) & (A538CD8 | A7B34CF | AC91BD0) & (A0CCCF2 | A7B34CF | ~AC91BD0)'}

# %%
s = combine_rule_using_and(s_rules, '&')
s
# Out:
# '((A430970 & AC91BD0) | (A0CCCF2 & ~A430970) | (A538CD8 & A933EC2 & AEDF6B1 & ~AC91BD0)) & ((A430970 & AC91BD0) | (A0CCCF2 & ~A430970) | (A224644 & A538CD8 & ~AC91BD0)) & ((A0CCCF2 | ~AC91BD0) & (A519FF7 | ~AC91BD0) & (A051928 | A538CD8 | AC91BD0) & (A538CD8 | AC91BD0 | AD67095) & (A051928 | AC91BD0 | ~A224644) & (AC91BD0 | AD67095 | ~A224644)) & (A933EC2 & (A0EF1D6 | A7B34CF | AC91BD0) & (A538CD8 | A7B34CF | AC91BD0) & (A0CCCF2 | A7B34CF | ~AC91BD0)) & ((A6B7121 & AC91BD0) | (A0CCCF2 & ~A6B7121))'

# %%
s2 = expr(s).to_cnf()
s2
# Out:
# And(A933EC2, Or(~AC91BD0, A519FF7), Or(AC91BD0, A538CD8, A051928), Or(AC91BD0, A538CD8, AD67095), Or(AC91BD0, ~A224644, A051928), Or(AC91BD0, ~A224644, AD67095), Or(AC91BD0, A0EF1D6, A7B34CF), Or(AC91BD0, A538CD8, A7B34CF), Or(~AC91BD0, A0CCCF2), Or(~A430970, AC91BD0, A538CD8), Or(A430970, A0CCCF2, A538CD8), Or(~A430970, AC91BD0, A224644), Or(A430970, A0CCCF2, A224644), Or(~A430970, AC91BD0, AEDF6B1), Or(A430970, A0CCCF2, AEDF6B1), Or(AC91BD0, A0CCCF2), Or(A0CCCF2, A6B7121), Or(AC91BD0, ~A6B7121))

# %%
simplified_func = convert_to_function('&', s2)
simplified_func
# Out:
# 'A933EC2 & (~AC91BD0 | A519FF7) & (AC91BD0 | A538CD8 | A051928) & (AC91BD0 | A538CD8 | AD67095) & (AC91BD0 | ~A224644 | A051928) & (AC91BD0 | ~A224644 | AD67095) & (AC91BD0 | A0EF1D6 | A7B34CF) & (AC91BD0 | A538CD8 | A7B34CF) & (~AC91BD0 | A0CCCF2) & (~A430970 | AC91BD0 | A538CD8) & (A430970 | A0CCCF2 | A538CD8) & (~A430970 | AC91BD0 | A224644) & (A430970 | A0CCCF2 | A224644) & (~A430970 | AC91BD0 | AEDF6B1) & (A430970 | A0CCCF2 | AEDF6B1) & (AC91BD0 | A0CCCF2) & (A0CCCF2 | A6B7121) & (AC91BD0 | ~A6B7121)'

# %%
sys_readable_rule = print_final_rule(s)
sys_readable_rule
# Out:
# "(((0, '<=', 63.35) & (0, '>', 63.05)) | ((0, '<=', 63.55) & (0, '>', 63.35)) | ((0, '>', 62.75) & (1, '<=', 57.05) & (1, '>', 55.75) & (0, '<=', 63.05))) & (((0, '<=', 63.35) & (0, '>', 63.05)) | ((0, '<=', 63.55) & (0, '>', 63.35)) | ((1, '>', 57.15) & (0, '>', 62.75) & (0, '<=', 63.05))) & (((0, '<=', 63.55) | (0, '<=', 63.05)) & ((1, '<=', 63.5) | (0, '<=', 63.05)) & ((0, '>', 60.55) | (0, '>', 62.75) | (0, '>', 63.05)) & ((0, '>', 62.75) | (0, '>', 63.05) | (1, '>', 62.25)) & ((0, '>', 60.55) | (0, '>', 63.05) | (1, '<=', 57.15)) & ((0, '>', 63.05) | (1, '>', 62.25) | (1, '<=', 57.15))) & ((1, '<=', 57.05) & ((1, '>', 55.3) | (0, '<=', 60.05) | (0, '>', 63.05)) & ((0, '>', 62.75) | (0, '<=', 60.05) | (0, '>', 63.05)) & ((0, '<=', 63.55) | (0, '<=', 60.05) | (0, '<=', 63.05))) & (((0, '<=', 63.45) & (0, '>', 63.05)) | ((0, '<=', 63.55) & (0, '>', 63.45)))"

# %%
def get_valid_predicate(rule):
    rule = rule.replace("&", "and").replace("|", "or").replace("0, '", 'depth ').replace("1, '", 'table ')
    rule = rule.replace("',", "")
    
    return rule

# %%
hum_readable_rule = get_valid_predicate(sys_readable_rule)
hum_readable_rule
# Out:
# '(((depth <= 63.35) and (depth > 63.05)) or ((depth <= 63.55) and (depth > 63.35)) or ((depth > 62.75) and (table <= 57.05) and (table > 55.75) and (depth <= 63.05))) and (((depth <= 63.35) and (depth > 63.05)) or ((depth <= 63.55) and (depth > 63.35)) or ((table > 57.15) and (depth > 62.75) and (depth <= 63.05))) and (((depth <= 63.55) or (depth <= 63.05)) and ((table <= 63.5) or (depth <= 63.05)) and ((depth > 60.55) or (depth > 62.75) or (depth > 63.05)) and ((depth > 62.75) or (depth > 63.05) or (table > 62.25)) and ((depth > 60.55) or (depth > 63.05) or (table <= 57.15)) and ((depth > 63.05) or (table > 62.25) or (table <= 57.15))) and ((table <= 57.05) and ((table > 55.3) or (depth <= 60.05) or (depth > 63.05)) and ((depth > 62.75) or (depth <= 60.05) or (depth > 63.05)) and ((depth <= 63.55) or (depth <= 60.05) or (depth <= 63.05))) and (((depth <= 63.45) and (depth > 63.05)) or ((depth <= 63.55) and (depth > 63.45)))'

# %%
def compute_final_rule_accuracy(class_index, rule):
    X = X_validation
    Y = Y_validation
    
    # Classification report
    Z = compute_rule_accuracy(class_index, rule, X)

    report = classification_report(Z, Y, output_dict = True)
    print(report[str(class_index)])
    
    
def compute_rule_accuracy(class_name, rule, dataset):
    """This method allows you to evaluate the whole rule given by 'rule' parameter to 'class_name'
    Returns an array of evaluated rule
    """
    
    pred = []
    
    # Store dataframe attribute names
    df_columns = list(df.columns.values)
    
    # Create an ordered dictionary in order to keep the order when we take values for given columns
    d_ = OrderedDict()
    
    # Create and optimize predicate given by the parameter
    test = Predicate(rule)
    s = OptimizedPredicateSet([test])
    
    for row in X_validation:
        
        # Create dictionary consisting of attribute names and corresponding row values for them
        for l, at in enumerate(df_columns):
            d_[at] = row[l]
        
        # Evaluate rule with created dictionary
        match = s.evaluate(dict(d_))
            
        # If the conditions from rule were met, append the class to final predictions array
        if len(match):
            pred.append(class_name)
        else:
            pred.append(-1)
            
    return pred

# %%
def attribute_rule_predict(class_name, rule, attr1, attr2, dataset):
    """Method used to get prediction only for two attributes given by 'attr1' and 'attr2' parameters
    This method is mainly used mainly for plotting purposes
    """ 
    
    # Create an empty predictions array
    pred = []
    
    # Create and optimize predicate given by the parameter
    test = Predicate(rule)
    s = OptimizedPredicateSet([test])
    
    # Store dataframe attribute names
    df_columns = list(df)
    
    # Create dictionary in which we will create the predicate
    d_ = dict()
    
    for row in dataset:
        
        # Get the attribute names by indexes from df_columns.
        d_[df_columns[attr1]] = row[0]
        d_[df_columns[attr2]] = row[1]
    
        # Evaluate rule with created dictionary
        match = s.evaluate(d_)
            
        # If the conditions from rule were met, append the class to final predictions array
        if len(match):
            pred.append(class_name)
        else:
            pred.append(-1)
            
    return pred

# %%
compute_final_rule_accuracy(4, hum_readable_rule)
# Out:
# {'precision': 0.10680412371134021, 'recall': 0.6590330788804071, 'f1-score': 0.18381831085876507, 'support': 393}

# %%
visualize_decision_boundaries(hum_readable_rule, 0, 1)

# %%
s = combine_rule_using_and(s_rules, '|')
s
# Out:
# '((A430970 & AC91BD0) | (A0CCCF2 & ~A430970) | (A538CD8 & A933EC2 & AEDF6B1 & ~AC91BD0)) | ((A430970 & AC91BD0) | (A0CCCF2 & ~A430970) | (A224644 & A538CD8 & ~AC91BD0)) | ((A0CCCF2 | ~AC91BD0) & (A519FF7 | ~AC91BD0) & (A051928 | A538CD8 | AC91BD0) & (A538CD8 | AC91BD0 | AD67095) & (A051928 | AC91BD0 | ~A224644) & (AC91BD0 | AD67095 | ~A224644)) | (A933EC2 & (A0EF1D6 | A7B34CF | AC91BD0) & (A538CD8 | A7B34CF | AC91BD0) & (A0CCCF2 | A7B34CF | ~AC91BD0)) | ((A6B7121 & AC91BD0) | (A0CCCF2 & ~A6B7121))'

# %%
sys_readable_rule = print_final_rule(s)
sys_readable_rule
# Out:
# "(((0, '<=', 63.35) & (0, '>', 63.05)) | ((0, '<=', 63.55) & (0, '>', 63.35)) | ((0, '>', 62.75) & (1, '<=', 57.05) & (1, '>', 55.75) & (0, '<=', 63.05))) | (((0, '<=', 63.35) & (0, '>', 63.05)) | ((0, '<=', 63.55) & (0, '>', 63.35)) | ((1, '>', 57.15) & (0, '>', 62.75) & (0, '<=', 63.05))) | (((0, '<=', 63.55) | (0, '<=', 63.05)) & ((1, '<=', 63.5) | (0, '<=', 63.05)) & ((0, '>', 60.55) | (0, '>', 62.75) | (0, '>', 63.05)) & ((0, '>', 62.75) | (0, '>', 63.05) | (1, '>', 62.25)) & ((0, '>', 60.55) | (0, '>', 63.05) | (1, '<=', 57.15)) & ((0, '>', 63.05) | (1, '>', 62.25) | (1, '<=', 57.15))) | ((1, '<=', 57.05) & ((1, '>', 55.3) | (0, '<=', 60.05) | (0, '>', 63.05)) & ((0, '>', 62.75) | (0, '<=', 60.05) | (0, '>', 63.05)) & ((0, '<=', 63.55) | (0, '<=', 60.05) | (0, '<=', 63.05))) | (((0, '<=', 63.45) & (0, '>', 63.05)) | ((0, '<=', 63.55) & (0, '>', 63.45)))"

# %%
hum_readable_rule = get_valid_predicate(sys_readable_rule)
hum_readable_rule
# Out:
# '(((depth <= 63.35) and (depth > 63.05)) or ((depth <= 63.55) and (depth > 63.35)) or ((depth > 62.75) and (table <= 57.05) and (table > 55.75) and (depth <= 63.05))) or (((depth <= 63.35) and (depth > 63.05)) or ((depth <= 63.55) and (depth > 63.35)) or ((table > 57.15) and (depth > 62.75) and (depth <= 63.05))) or (((depth <= 63.55) or (depth <= 63.05)) and ((table <= 63.5) or (depth <= 63.05)) and ((depth > 60.55) or (depth > 62.75) or (depth > 63.05)) and ((depth > 62.75) or (depth > 63.05) or (table > 62.25)) and ((depth > 60.55) or (depth > 63.05) or (table <= 57.15)) and ((depth > 63.05) or (table > 62.25) or (table <= 57.15))) or ((table <= 57.05) and ((table > 55.3) or (depth <= 60.05) or (depth > 63.05)) and ((depth > 62.75) or (depth <= 60.05) or (depth > 63.05)) and ((depth <= 63.55) or (depth <= 60.05) or (depth <= 63.05))) or (((depth <= 63.45) and (depth > 63.05)) or ((depth <= 63.55) and (depth > 63.45)))'

# %%
compute_final_rule_accuracy(4, hum_readable_rule)
# Out:
# {'precision': 0.33979381443298967, 'recall': 0.5312701482914249, 'f1-score': 0.41448692152917505, 'support': 1551}

# %%
visualize_decision_boundaries(hum_readable_rule, 0, 1)

# %%
data['cut'].unique()

# %%
from itertools import product

import matplotlib.pyplot as plt

from sklearn import datasets

X = X_validation
Y = Y_validation

# Plotting decision regions
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))

f, axarr = plt.subplots(figsize=(10, 8))

Z = rfclf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

axarr.contourf(xx, yy, Z, alpha=0.4)
axarr.scatter(X[:, 0], X[:, 1], c=Y, s=20, edgecolor='k')
axarr.set_title("Random Forest")

plt.show()

# %%
rule_dict = {}
var_dict = {}

rules, s_rules = combine_forest_rules(rfclf, "Ideal", rule_dict, var_dict)
rules

# %%
s_rules

# %%
s = combine_rule_using_and(s_rules, '&')
s

# %%
s2 = expr(s).to_cnf()
s2

# %%
simplified_func = convert_to_function('&', s2)
simplified_func

# %%
sys_readable_rule = print_final_rule(s)
sys_readable_rule

# %%
hum_readable_rule = get_valid_predicate(sys_readable_rule)
hum_readable_rule

# %%
compute_final_rule_accuracy(0, hum_readable_rule)

# %%
visualize_decision_boundaries(hum_readable_rule, 0, 1)

# %%
rule_dict = {}
var_dict = {}

rules, s_rules = combine_forest_rules(rfclf, "Good", rule_dict, var_dict)
rules

# %%
s_rules

# %%
s = combine_rule_using_and(s_rules, '&')
s

# %%
s2 = expr(s).to_cnf()
s2

# %%
simplified_func = convert_to_function('&', s2)
simplified_func

# %%
sys_readable_rule = print_final_rule(s)
sys_readable_rule

# %%
hum_readable_rule = get_valid_predicate(sys_readable_rule)
hum_readable_rule

# %%
compute_final_rule_accuracy(2, hum_readable_rule)

# %%
def visualize_decision_boundaries(rule, attr1, attr2):
    """
    This function is used to draw decision boundaries for 2 attributes which will be used to predict the output
    """
    
    # Create a dataset from validation data having only columns specified by paramters
    X = X_validation[:, [attr1, attr2]]
    Y = Y_validation

    # Plotting decision regions
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))

    f, axarr = plt.subplots(figsize=(10, 8))

    # Create prediction
    ravel_ = np.c_[xx.ravel(), yy.ravel()]
    Z = np.array(attribute_rule_predict(1, rule, attr1, attr2, ravel_))
    Z = Z.reshape(xx.shape)
    
    # Plot predicted dots
    axarr.contourf(xx, yy, Z, alpha=0.5)
    axarr.scatter(X[:, 0], X[:, 1], c=Y, s=50, edgecolor='k')
    axarr.set_title("When random forest is very sure")

    plt.show()

# %%
visualize_decision_boundaries(hum_readable_rule, 0, 1)
